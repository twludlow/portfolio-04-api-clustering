# %% [markdown]
# # Yelp Fusion API exploration - 1/2/19

# %% [markdown]
# ## Britt Allen, Bernard Kurka, Thomas Ludlow - NY-DSI-6

# %% [markdown]
# Figure out how to pull `price` and supporting data directly from Yelp using *Fusion API*.

# %% [markdown]
# ### Resources

# %% [markdown]
# GitHub:
#  - https://github.com/Yelp/yelp-python
#  - https://github.com/gfairchild/yelpapi *(Best library)*
#   - https://github.com/gfairchild/yelpapi/blob/master/examples/examples.py

# %% [markdown]
# Endpoint Documentation: https://www.yelp.com/developers/documentation/v3/business

# %% [markdown]
# Using regular search, a location-based query is formatted like this:
# `https://www.yelp.com/search?find_loc=10128`

# %% [markdown]
# ```
# My App
# Client ID
# ea2TodAq4YX-4W3lzSJrcA
#
# API Key
# 21Pt2l8__qgIdL0ZpgYC_yWblJ_O8_vJ3_-tIybHDyuQl9oVBXAzAXQWqMmIrz7idLyc7owv4-lfSON0QjKJN4pvQei4rUQAGSZcGcVTQc4HtBseUcztUPkVrAItXHYx
# ```

# %% [markdown]
# ### Libraries

# %%
import numpy as np
import pandas as pd
import json
from yelpapi import YelpAPI

# %%
api_key = '21Pt2l8__qgIdL0ZpgYC_yWblJ_O8_vJ3_-tIybHDyuQl9oVBXAzAXQWqMmIrz7idLyc7owv4-lfSON0QjKJN4pvQei4rUQAGSZcGcVTQc4HtBseUcztUPkVrAItXHYx'
yelp_api = YelpAPI(api_key, timeout_s=1.0)

# %% [markdown]
# `search_results = yelp_api.search_query(args)`

# %% [markdown]
# Search Query:
# `response = yelp_api.search_query(term='ice cream', location='austin, tx', sort_by='rating', limit=5)`

# %%
response = yelp_api.search_query(location='10128')

# %%
response
# Out:
# {'businesses': [{'id': 'UGECJrPSWy0n7PXykBBWAQ',
#    'alias': 'two-little-red-hens-new-york-4',
#    'name': 'Two Little Red Hens',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gF02Oh2PfE2OS7Nz3MqV4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/two-little-red-hens-new-york-4?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#    'review_count': 2342,
#    'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.777528, 'longitude': -73.9517869},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1652 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1652 2nd Ave', 'New York, NY 10028']},
#    'phone': '+12124520476',
#    'display_phone': '(212) 452-0476',
#    'distance': 459.146874340976},
#   {'id': 'jVncyqXwlx_D9f2xZn05tg',
#    'alias': 'the-metropolitan-museum-of-art-new-york-3',
#    'name': 'The Metropolitan Museum of Art',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/IYGL2yl2Pu6P5wj3rKI_kw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-metropolitan-museum-of-art-new-york-3?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#    'review_count': 2634,
#    'categories': [{'alias': 'artmuseums', 'title': 'Art Museums'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.779254271604,
#     'longitude': -73.9628841731528},
#    'transactions': [],
#    'location': {'address1': '1000 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1000 5th Ave', 'New York, NY 10028']},
#    'phone': '+12125357710',
#    'display_phone': '(212) 535-7710',
#    'distance': 1004.6430146994313},
#   {'id': '9pMhRYYgV7E9L7pzECtJKA',
#    'alias': 'the-drunken-munkey-new-york-5',
#    'name': 'The Drunken Munkey',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/GgyYVXAY1-AFFZHYeBa6dQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-drunken-munkey-new-york-5?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#    'review_count': 820,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.78098, 'longitude': -73.94751},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '338 E 92nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['338 E 92nd St', 'New York, NY 10128']},
#    'phone': '+16469984600',
#    'display_phone': '(646) 998-4600',
#    'distance': 328.5901863671552},
#   {'id': 'kmcgUxWhwlbmC-FAMTEF2g',
#    'alias': 'cafe-d-alsace-new-york',
#    'name': "Cafe D'Alsace",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VR3Zlw9vTGVKwyLlYR7dQw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/cafe-d-alsace-new-york?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#    'review_count': 1105,
#    'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77916, 'longitude': -73.95104},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1695 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1695 2nd Ave', 'New York, NY 10128']},
#    'phone': '+12127225133',
#    'display_phone': '(212) 722-5133',
#    'distance': 276.14800279698335},
#   {'id': 'Wbmqg0TkOVkzNh3HrJ9DIQ',
#    'alias': 'vietnaam-new-york',
#    'name': 'Vietnaam',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/oLY9ouWW0YE3QoeNRSlIwA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vietnaam-new-york?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#    'review_count': 670,
#    'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7791481018066,
#     'longitude': -73.9504165649414},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1700 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1700 2nd Ave', 'New York, NY 10128']},
#    'phone': '+12127220558',
#    'display_phone': '(212) 722-0558',
#    'distance': 286.0158773248678},
#   {'id': 'hJ1xHZbD7IRlVFNfoe5HGA',
#    'alias': 'shake-shack-new-york-45',
#    'name': 'Shake Shack',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FXamkkgwh8HmsNT86nQkLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/shake-shack-new-york-45?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#    'review_count': 1317,
#    'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'},
#     {'alias': 'icecream', 'title': 'Ice Cream & Frozen Yogurt'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.778888, 'longitude': -73.955004},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '154 E 86th St',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10120',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['154 E 86th St', 'New York, NY 10120']},
#    'phone': '+16462375035',
#    'display_phone': '(646) 237-5035',
#    'distance': 432.7113417098861},
#   {'id': 'izRJeBfDQYJmd6ibIQ6Mfg',
#    'alias': 'mughlai-indian-cuisine-new-york-4',
#    'name': 'Mughlai Indian Cuisine',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/DNsKeryjY2uBsavRUdc2hw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/mughlai-indian-cuisine-new-york-4?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#    'review_count': 371,
#    'categories': [{'alias': 'indpak', 'title': 'Indian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.78002, 'longitude': -73.94978},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1724 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1724 2nd Ave', 'New York, NY 10128']},
#    'phone': '+12127226262',
#    'display_phone': '(212) 722-6262',
#    'distance': 221.40143722070806},
#   {'id': 'yN5rHxaIZMk6KFrbDNgZgA',
#    'alias': 'lukes-lobster-upper-east-side-new-york',
#    'name': "Luke's Lobster Upper East Side",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/3tKTggoDk8cj0QBseU_sMg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lukes-lobster-upper-east-side-new-york?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#    'review_count': 1108,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7747308470083,
#     'longitude': -73.9545491922026},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '242 E 81st St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['242 E 81st St', 'New York, NY 10028']},
#    'phone': '+12122494241',
#    'display_phone': '(212) 249-4241',
#    'distance': 813.9319163878786},
#   {'id': '2f0EWTvp3YDtGNKEEXKKhA',
#    'alias': 'naruto-ramen-new-york',
#    'name': 'Naruto Ramen',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/ysCWJLpeJdfm7gr590NBhw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/naruto-ramen-new-york?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#    'review_count': 852,
#    'categories': [{'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 3.5,
#    'coordinates': {'latitude': 40.78117, 'longitude': -73.9525},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1596 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1596 3rd Ave', 'New York, NY 10128']},
#    'phone': '+12122897803',
#    'display_phone': '(212) 289-7803',
#    'distance': 106.00897565353725},
#   {'id': '6tGW6KMFB1rLGInE6sB3KA',
#    'alias': 'kaia-wine-bar-new-york',
#    'name': 'Kaia Wine Bar',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yP2op7-Oddsly0iL0KrlEA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/kaia-wine-bar-new-york?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#    'review_count': 377,
#    'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'southafrican', 'title': 'South African'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7819, 'longitude': -73.95197},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1614 3rd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1614 3rd Ave', 'New York, NY 10128']},
#    'phone': '+12127220490',
#    'display_phone': '(212) 722-0490',
#    'distance': 67.37367801660733},
#   {'id': 'doBm7WkYKNG-KRExevrRtA',
#    'alias': 'dtut-new-york',
#    'name': 'DTUT',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gzCYB4N6VQzAA_7juBVXOw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/dtut-new-york?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#    'review_count': 460,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7808542200993,
#     'longitude': -73.949341175468},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '1744 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1744 2nd Ave', 'New York, NY 10128']},
#    'phone': '+12124106449',
#    'display_phone': '(212) 410-6449',
#    'distance': 192.74380542928796},
#   {'id': '-P7qAIG1wr_gXW3nzIq5TA',
#    'alias': 'flex-mussels-new-york',
#    'name': 'Flex Mussels',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-AfgdSry35P1TRuZeRM4sQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/flex-mussels-new-york?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#    'review_count': 968,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'desserts', 'title': 'Desserts'},
#     {'alias': 'belgian', 'title': 'Belgian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.77637, 'longitude': -73.95646},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '174 East 82nd St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['174 East 82nd St', 'New York, NY 10028']},
#    'phone': '+12127177772',
#    'display_phone': '(212) 717-7772',
#    'distance': 732.5006478691604},
#   {'id': 'BNHvVLzl4SQ8Da9mjIPH1A',
#    'alias': 'pye-boat-noodle-new-york-3',
#    'name': 'Pye Boat Noodle',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/CI8AXMdrGEuSek-CYNKGCA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pye-boat-noodle-new-york-3?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#    'review_count': 375,
#    'categories': [{'alias': 'thai', 'title': 'Thai'},
#     {'alias': 'noodles', 'title': 'Noodles'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.779697, 'longitude': -73.950767},
#    'transactions': ['delivery'],
#    'price': '$$',
#    'location': {'address1': '1711 Second Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1711 Second Ave', 'New York, NY 10128']},
#    'phone': '+12124273077',
#    'display_phone': '(212) 427-3077',
#    'distance': 222.88801153185324},
#   {'id': 'OAqsZMbjv66nOMqlimnYuQ',
#    'alias': 'uva-new-york',
#    'name': 'Uva',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/OKw0xxKFXVRPNTRFx6v2Dg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/uva-new-york?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#    'review_count': 2117,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7722, 'longitude': -73.95566},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1486 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1486 2nd Ave', 'New York, NY 10075']},
#    'phone': '+12124724552',
#    'display_phone': '(212) 472-4552',
#    'distance': 1111.2341910475736},
#   {'id': 'q2D80--iDkSwf_OKsS-jdA',
#    'alias': 'la-pulperia-ues-new-york-3',
#    'name': 'La Pulperia UES',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ekIj_fmqOSf3IFhtb5hWvQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-pulperia-ues-new-york-3?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#    'review_count': 643,
#    'categories': [{'alias': 'latin', 'title': 'Latin American'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7766202, 'longitude': -73.9523275},
#    'transactions': ['delivery', 'pickup', 'restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '1626 2nd Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1626 2nd Ave', 'New York, NY 10028']},
#    'phone': '+12129330757',
#    'display_phone': '(212) 933-0757',
#    'distance': 564.4878051491295},
#   {'id': 'r-izNItUH4ugnFodUOZX2A',
#    'alias': 'international-wings-factory-new-york',
#    'name': 'International Wings Factory',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PUDtSdVA9__AlrB03rBwig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/international-wings-factory-new-york?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#    'review_count': 377,
#    'categories': [{'alias': 'chicken_wings', 'title': 'Chicken Wings'},
#     {'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7801834538692,
#     'longitude': -73.9467542692273},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1762 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1762 1st Ave', 'New York, NY 10128']},
#    'phone': '+12123482627',
#    'display_phone': '(212) 348-2627',
#    'distance': 421.88350557410814},
#   {'id': '0vg2Z-HPwkyVVX613j2ysg',
#    'alias': 'pengs-noodle-folk-new-york-2',
#    'name': "Peng's Noodle Folk",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3hssUzkkn6YQORnam2QyBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/pengs-noodle-folk-new-york-2?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#    'review_count': 338,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'ramen', 'title': 'Ramen'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.77726, 'longitude': -73.94932},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1659 1st Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10028',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1659 1st Ave', 'New York, NY 10028']},
#    'phone': '+12123482878',
#    'display_phone': '(212) 348-2878',
#    'distance': 510.5500464969724},
#   {'id': 'MidK0WWI0_1tZL8AuR7Jhw',
#    'alias': 'candle-79-new-york',
#    'name': 'Candle 79',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BpkVGVTYKApjOZ8gJjfX4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/candle-79-new-york?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#    'review_count': 1249,
#    'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#     {'alias': 'vegan', 'title': 'Vegan'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.774627, 'longitude': -73.958697},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '154 E 79th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10075',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['154 E 79th St', 'New York, NY 10075']},
#    'phone': '+12125377179',
#    'display_phone': '(212) 537-7179',
#    'distance': 994.4218075733963},
#   {'id': 'DpZBA0-f7Um9lvnp1zZM2A',
#    'alias': 'earls-beer-and-cheese-new-york',
#    'name': "Earl's Beer & Cheese",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/famNEa6UXueVsF51-9nDRg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/earls-beer-and-cheese-new-york?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#    'review_count': 562,
#    'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78729, 'longitude': -73.95152},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '1259 Park Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10029',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1259 Park Ave', 'New York, NY 10029']},
#    'phone': '+12122891581',
#    'display_phone': '(212) 289-1581',
#    'distance': 629.256535645449},
#   {'id': '4FtqGBB96denVJu8KnuGKg',
#    'alias': 'the-milton-new-york',
#    'name': 'The Milton',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/NLXd4elZ0ZS1Ud0nDo1TgA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/the-milton-new-york?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#    'review_count': 356,
#    'categories': [{'alias': 'irish', 'title': 'Irish'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'british', 'title': 'British'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.78123, 'longitude': -73.94893},
#    'transactions': ['delivery', 'pickup'],
#    'price': '$$',
#    'location': {'address1': '1754 Second Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10128',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['1754 Second Ave', 'New York, NY 10128']},
#    'phone': '+12123691900',
#    'display_phone': '(212) 369-1900',
#    'distance': 209.26661196967945}],
#  'total': 619,
#  'region': {'center': {'longitude': -73.95137786865234,
#    'latitude': 40.781645578902086}}}

# %%
len(response['businesses'])
# Out:
# 20

# %%
response = yelp_api.search_query(location='dresher, PA', sort_by='review_count', limit=50)

# %%
response['businesses']
# Out:
# [{'id': 'rAe-1HU5Z-DuUXEbzASXDA',
#   'alias': 'mad-mex-willow-grove-willow-grove-2',
#   'name': 'Mad Mex - Willow Grove',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Y5AKNVpWZlp7tx_m8AMtWg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mad-mex-willow-grove-willow-grove-2?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 363,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'tex-mex', 'title': 'Tex-Mex'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.147965, 'longitude': -75.1282592},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '2862 W Moreland Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Willow Grove',
#    'zip_code': '19090',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['2862 W Moreland Rd', 'Willow Grove, PA 19090']},
#   'phone': '+12674955000',
#   'display_phone': '(267) 495-5000',
#   'distance': 3454.4141918630726},
#  {'id': 'w_B0phzyFXPmeiVlzQrq6A',
#   'alias': 'cantina-feliz-fort-washington',
#   'name': 'Cantina Feliz',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/eCg8z60qY8ZBEG9gikQFWA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/cantina-feliz-fort-washington?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 358,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.136374, 'longitude': -75.213808},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '424 S Bethlehem Pike',
#    'address2': '',
#    'address3': '',
#    'city': 'Fort Washington',
#    'zip_code': '19034',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['424 S Bethlehem Pike', 'Fort Washington, PA 19034']},
#   'phone': '+12156461320',
#   'display_phone': '(215) 646-1320',
#   'distance': 3950.7286085774513},
#  {'id': '2Q1R2OhBbAQ581vK_r7NhA',
#   'alias': 'ooka-restaurant-willow-grove',
#   'name': 'Ooka Restaurant',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vlL1qCrXBGHyyJUPSeEbPw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ooka-restaurant-willow-grove?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 333,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.15676, 'longitude': -75.12175},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1109 Easton Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Willow Grove',
#    'zip_code': '19090',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1109 Easton Rd', 'Willow Grove, PA 19090']},
#   'phone': '+12156597688',
#   'display_phone': '(215) 659-7688',
#   'distance': 4300.544615641737},
#  {'id': 'JmzNw0WCPmZPZdq5nx9brg',
#   'alias': 'kitchen-bar-abington',
#   'name': 'Kitchen Bar',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/PTtRRJmMoZLt8QflRT6mDQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/kitchen-bar-abington?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 324,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'venues', 'title': 'Venues & Event Spaces'},
#    {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.1249122619629,
#    'longitude': -75.1177673339844},
#   'transactions': ['restaurant_reservation', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1482 Old York Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Abington',
#    'zip_code': '19001',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1482 Old York Rd', 'Abington, PA 19001']},
#   'phone': '+12155769766',
#   'display_phone': '(215) 576-9766',
#   'distance': 4562.159885437793},
#  {'id': 'uP42QDUxC2lxz15BUDbFnA',
#   'alias': 'the-cheesecake-factory-willow-grove',
#   'name': 'The Cheesecake Factory',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/g4RnPrGZnfqreb34izOkyg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-cheesecake-factory-willow-grove?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 290,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.1402781186111,
#    'longitude': -75.1253705174744},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '2500 W Moreland Rd',
#    'address2': 'Ste 3225',
#    'address3': '',
#    'city': 'Willow Grove',
#    'zip_code': '19090',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['2500 W Moreland Rd',
#     'Ste 3225',
#     'Willow Grove, PA 19090']},
#   'phone': '+12156590270',
#   'display_phone': '(215) 659-0270',
#   'distance': 3589.6285669834024},
#  {'id': 'vqXsnIRg6Dh4oJ7K0396Jg',
#   'alias': 'zakes-cakes-and-cafe-fort-washington',
#   'name': 'Zakes Cakes & Cafe',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/VB0JQ8YTqcOrsGbIGtnRkQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/zakes-cakes-and-cafe-fort-washington?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 282,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'customcakes', 'title': 'Custom Cakes'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.1352, 'longitude': -75.21439},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '444 S Bethlehem Pike',
#    'address2': '',
#    'address3': '',
#    'city': 'Fort Washington',
#    'zip_code': '19034',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['444 S Bethlehem Pike', 'Fort Washington, PA 19034']},
#   'phone': '+12156547600',
#   'display_phone': '(215) 654-7600',
#   'distance': 3976.5632371777315},
#  {'id': 'we1k41J13buaXeLrPlYFyg',
#   'alias': 'brick-house-tavern-tap-willow-grove-2',
#   'name': 'Brick House Tavern + Tap',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5UNuGu3jDO-mgAGKvmiiMA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/brick-house-tavern-tap-willow-grove-2?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 272,
#   'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.16724, 'longitude': -75.12632},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '2402 Easton Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Willow Grove',
#    'zip_code': '19090',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['2402 Easton Rd', 'Willow Grove, PA 19090']},
#   'phone': '+12156755767',
#   'display_phone': '(215) 675-5767',
#   'distance': 4619.918411781642},
#  {'id': 'fq44yNPMuN0dF5ZHdDuvYw',
#   'alias': 'movie-tavern-flourtown-flourtown',
#   'name': 'Movie Tavern Flourtown',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/UjjuWJyTo4_f7rtLX8q8aQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/movie-tavern-flourtown-flourtown?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 259,
#   'categories': [{'alias': 'dinnertheater', 'title': 'Dinner Theater'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 40.110714, 'longitude': -75.212011},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1844 Bethlehem Pike',
#    'address2': '',
#    'address3': '',
#    'city': 'Flourtown',
#    'zip_code': '19031',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1844 Bethlehem Pike', 'Flourtown, PA 19031']},
#   'phone': '+12158664950',
#   'display_phone': '(215) 866-4950',
#   'distance': 4998.579802710934},
#  {'id': '6iFfVfpSlMNSzxvrG6P6jw',
#   'alias': 'bernies-restaurant-and-bar-glenside-jenkintown-5',
#   'name': "Bernie's Restaurant & Bar - Glenside",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zqVLSSAjw7M7LwX8viQrEg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bernies-restaurant-and-bar-glenside-jenkintown-5?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 256,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.1012468210128,
#    'longitude': -75.1388816775622},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '391 Highland Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Jenkintown',
#    'zip_code': '19046',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['391 Highland Ave', 'Jenkintown, PA 19046']},
#   'phone': '+12155725927',
#   'display_phone': '(215) 572-5927',
#   'distance': 4969.218777487522},
#  {'id': 'ZQc6EvnfQXtIK-8w-d0N5Q',
#   'alias': 'mad-rex-philadelphia',
#   'name': 'Mad Rex',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/o-Q0MLFXvRC6-sQxlrkqwg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mad-rex-philadelphia?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 235,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'bartenders', 'title': 'Bartenders'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 39.9652211, 'longitude': -75.1345749},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1000 Frankford Ave',
#    'address2': 'Ste 1',
#    'address3': '',
#    'city': 'Philadelphia',
#    'zip_code': '19125',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1000 Frankford Ave',
#     'Ste 1',
#     'Philadelphia, PA 19125']},
#   'phone': '+12677737566',
#   'display_phone': '(267) 773-7566',
#   'distance': 19684.359856716226},
#  {'id': 'Fs3Iys5SNG5AOiQ_keM79g',
#   'alias': 'nadias-thai-willow-grove',
#   'name': "Nadia's Thai",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/X6lMn3tzGI9UUwg-Ietzow/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nadias-thai-willow-grove?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 227,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'desserts', 'title': 'Desserts'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.14137, 'longitude': -75.1167},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '3 Easton Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Willow Grove',
#    'zip_code': '19090',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['3 Easton Rd', 'Willow Grove, PA 19090']},
#   'phone': '+12154503534',
#   'display_phone': '(215) 450-3534',
#   'distance': 4321.250492485142},
#  {'id': 'gpYBhnTk4KzvvH83TsZiQg',
#   'alias': 'humptys-dumplings-glenside-5',
#   'name': "Humpty's Dumplings",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/bfrG5B3-wHPp5uhSRfSukg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/humptys-dumplings-glenside-5?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 222,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.1063423, 'longitude': -75.1472876},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '277 N Keswick Ave',
#    'address2': None,
#    'address3': '',
#    'city': 'Glenside',
#    'zip_code': '19038',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['277 N Keswick Ave', 'Glenside, PA 19038']},
#   'phone': '+12159356180',
#   'display_phone': '(215) 935-6180',
#   'distance': 4166.412806336337},
#  {'id': 'C2vKa-eZFVBrfFGYXxvXFw',
#   'alias': 'senor-salsa-abington',
#   'name': 'Senor Salsa',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/VVM9WT-muNczxMTo3esHIw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/senor-salsa-abington?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 214,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.119112, 'longitude': -75.118793},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '1301 Old York Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Abington',
#    'zip_code': '19001',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1301 Old York Rd', 'Abington, PA 19001']},
#   'phone': '+12158879600',
#   'display_phone': '(215) 887-9600',
#   'distance': 4759.63127679685},
#  {'id': 'tdXYmpPzMuBzm9bN46PG3w',
#   'alias': 'millers-ale-house-willow-grove-willow-grove-2',
#   'name': "Miller's Ale House - Willow Grove",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VEqiWn1V1SVmsQBnYhUaMg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/millers-ale-house-willow-grove-willow-grove-2?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 207,
#   'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.165396, 'longitude': -75.12694},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2300 Easton Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Willow Grove',
#    'zip_code': '19090',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['2300 Easton Rd', 'Willow Grove, PA 19090']},
#   'phone': '+12156570515',
#   'display_phone': '(215) 657-0515',
#   'distance': 4450.810688727554},
#  {'id': 'loD9IlH0q4stjff3NHhWYw',
#   'alias': 'the-sweet-taco-willow-grove',
#   'name': 'The Sweet Taco',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/lNZdRW8QqAKvtn5zZEJZTQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-sweet-taco-willow-grove?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 200,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.1562538, 'longitude': -75.1417236},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '4001 Welsh Rd',
#    'address2': None,
#    'address3': '',
#    'city': 'Willow Grove',
#    'zip_code': '19090',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['4001 Welsh Rd', 'Willow Grove, PA 19090']},
#   'phone': '+12156574500',
#   'display_phone': '(215) 657-4500',
#   'distance': 2893.7467088406493},
#  {'id': 'T9nNz9-3mfNga0T0Nfzvsw',
#   'alias': 'ottos-brauhaus-horsham',
#   'name': "Otto's Brauhaus",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/T1vwAvjvsj7KCN-PdQu8JQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ottos-brauhaus-horsham?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 190,
#   'categories': [{'alias': 'german', 'title': 'German'},
#    {'alias': 'pubs', 'title': 'Pubs'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.1751634428835,
#    'longitude': -75.1286849992268},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '233 Easton Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Horsham',
#    'zip_code': '19044',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['233 Easton Rd', 'Horsham, PA 19044']},
#   'phone': '+12156751864',
#   'display_phone': '(215) 675-1864',
#   'distance': 5106.66676612617},
#  {'id': 'V_tkg5iqbsR9TcrivrDgzg',
#   'alias': 'bonefish-grill-willow-grove',
#   'name': 'Bonefish Grill',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/yj3IcFlq6lrsnfLlGlJFRA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bonefish-grill-willow-grove?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 175,
#   'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.1551498406712,
#    'longitude': -75.1202684891822},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1015 Easton Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Willow Grove',
#    'zip_code': '19090',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1015 Easton Rd', 'Willow Grove, PA 19090']},
#   'phone': '+12156595854',
#   'display_phone': '(215) 659-5854',
#   'distance': 4354.12786585206},
#  {'id': '8CG5nPzDkMkQEsH1k_hdVA',
#   'alias': 'anthonys-coal-fired-pizza-horsham',
#   'name': "Anthony's Coal Fired Pizza",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ws7r7CWg3v7sRMC8suUnEQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/anthonys-coal-fired-pizza-horsham?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 174,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.158299, 'longitude': -75.143884},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '100 Welsh Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Horsham',
#    'zip_code': '19044',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['100 Welsh Rd', 'Horsham, PA 19044']},
#   'phone': '+12156571113',
#   'display_phone': '(215) 657-1113',
#   'distance': 2850.77222623027},
#  {'id': '9yxl1mB9Cx_dZiSWUsdXrQ',
#   'alias': 'tonellis-pizza-pub-horsham',
#   'name': "Tonelli's Pizza Pub",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/umOAPR6Vn4ZJq88FP9r4OA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tonellis-pizza-pub-horsham?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 163,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.17639, 'longitude': -75.1277999},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '278 Easton Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Horsham',
#    'zip_code': '19044',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['278 Easton Rd', 'Horsham, PA 19044']},
#   'phone': '+12156753220',
#   'display_phone': '(215) 675-3220',
#   'distance': 5273.511600047431},
#  {'id': 'gHE7ClRmr8CZp5qw-bo4UA',
#   'alias': 'magerks-pub-and-grill-fort-washington',
#   'name': "MaGerk's Pub & Grill",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/JyFGMkB8Akdlv9aZllK6Zg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/magerks-pub-and-grill-fort-washington?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 147,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'pubs', 'title': 'Pubs'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.1229629516602,
#    'longitude': -75.2177963256836},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '582 S Bethlehem Pike',
#    'address2': '',
#    'address3': '',
#    'city': 'Fort Washington',
#    'zip_code': '19034',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['582 S Bethlehem Pike', 'Fort Washington, PA 19034']},
#   'phone': '+12159483329',
#   'display_phone': '(215) 948-3329',
#   'distance': 4674.114251156331},
#  {'id': 'F9N4o6uuocwm3lPkhmK3yQ',
#   'alias': 'nagomi-glenside-4',
#   'name': 'Nagomi',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/5cwpgAof3L5RPxIJmFRvrw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/nagomi-glenside-4?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 146,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.105167, 'longitude': -75.147372},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '256 N Keswick Ave',
#    'address2': None,
#    'address3': None,
#    'city': 'Glenside',
#    'zip_code': '19038',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['256 N Keswick Ave', 'Glenside, PA 19038']},
#   'phone': '+12158876666',
#   'display_phone': '(215) 887-6666',
#   'distance': 4253.572637191125},
#  {'id': 'VvqYQ98FjO0iYpKHgu91fw',
#   'alias': 'jules-thin-crust-jenkintown',
#   'name': 'Jules Thin Crust',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/kbTRYwi_GWPxcgL6atJHiA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jules-thin-crust-jenkintown?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 144,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.105356475646, 'longitude': -75.12344821409},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '816 Old York Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Jenkintown',
#    'zip_code': '19046',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['816 Old York Rd', 'Jenkintown, PA 19046']},
#   'phone': '+12158865555',
#   'display_phone': '(215) 886-5555',
#   'distance': 5392.261647766779},
#  {'id': 'ETZK5PuCsVfQ7ElXckDTPw',
#   'alias': 'ban-ban-asian-bistro-abington-2',
#   'name': 'Ban Ban Asian Bistro',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/bErPLhTcQau-pNxYNyz7NQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ban-ban-asian-bistro-abington-2?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 141,
#   'categories': [{'alias': 'bubbletea', 'title': 'Bubble Tea'},
#    {'alias': 'chinese', 'title': 'Chinese'},
#    {'alias': 'sushi', 'title': 'Sushi Bars'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.1270790528143,
#    'longitude': -75.1167098432779},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$$',
#   'location': {'address1': '1533 Old York Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Abington',
#    'zip_code': '19001',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1533 Old York Rd', 'Abington, PA 19001']},
#   'phone': '+12152775653',
#   'display_phone': '(215) 277-5653',
#   'distance': 4564.5071820728945},
#  {'id': 'Ex3sDfs_cdSnDqOb_qM5RA',
#   'alias': 'elevation-burger-willow-grove',
#   'name': 'Elevation Burger',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4ga35RgfQbnIvb3JIfirDQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/elevation-burger-willow-grove?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 136,
#   'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'vegetarian', 'title': 'Vegetarian'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.155628211323, 'longitude': -75.140056646149},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '3945 Welsh Rd',
#    'address2': None,
#    'address3': '',
#    'city': 'Willow Grove',
#    'zip_code': '19090',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['3945 Welsh Rd', 'Willow Grove, PA 19090']},
#   'phone': '+12156591008',
#   'display_phone': '(215) 659-1008',
#   'distance': 2904.320159412698},
#  {'id': 'WL-0PLW5IzdnyUHGmiOrgQ',
#   'alias': 'keswick-tavern-glenside',
#   'name': 'Keswick Tavern',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/76FLIZkhkP8wiDdWgP6P3Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/keswick-tavern-glenside?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 129,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'newamerican', 'title': 'American (New)'},
#    {'alias': 'greek', 'title': 'Greek'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.1062536, 'longitude': -75.1476922},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '294 N Keswick Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Glenside',
#    'zip_code': '19038',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['294 N Keswick Ave', 'Glenside, PA 19038']},
#   'phone': '+12158864277',
#   'display_phone': '(215) 886-4277',
#   'distance': 4141.192085471115},
#  {'id': 'RCpFAdBZJM9ucpVMcYXiVA',
#   'alias': 'gummlai-thai-abington',
#   'name': 'Gummlai Thai',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1tCriIzkw7NiuFOUvcHaMQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/gummlai-thai-abington?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 128,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.1238753, 'longitude': -75.1330234},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1170 Easton Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Abington',
#    'zip_code': '19001',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1170 Easton Rd', 'Abington, PA 19001']},
#   'phone': '+12155768424',
#   'display_phone': '(215) 576-8424',
#   'distance': 3452.341027197215},
#  {'id': 'qbwlS2CwXyRoULFiB_0zVQ',
#   'alias': 'olive-garden-italian-restaurant-willow-grove-2',
#   'name': 'Olive Garden Italian Restaurant',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/U3FUjVgnpED8urZ6EqfGPg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/olive-garden-italian-restaurant-willow-grove-2?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 123,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 40.141033, 'longitude': -75.116764},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2328 W Moreland Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Willow Grove',
#    'zip_code': '19090',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['2328 W Moreland Rd', 'Willow Grove, PA 19090']},
#   'phone': '+12158300285',
#   'display_phone': '(215) 830-0285',
#   'distance': 4294.248245548392},
#  {'id': 'STwdgdVYWm-pBDF1JIpAVA',
#   'alias': 'vic-sushi-and-thai-cuisine-willow-grove',
#   'name': 'Vic Sushi & Thai Cuisine',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/OuIAOxdPUWoEWOsMBEvpfg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/vic-sushi-and-thai-cuisine-willow-grove?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 122,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'salad', 'title': 'Salad'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.1698003, 'longitude': -75.1270294},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2720 Easton Rd',
#    'address2': None,
#    'address3': '',
#    'city': 'Willow Grove',
#    'zip_code': '19090',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['2720 Easton Rd', 'Willow Grove, PA 19090']},
#   'phone': '+12156753993',
#   'display_phone': '(215) 675-3993',
#   'distance': 4769.055651632019},
#  {'id': 'sYgyAxvuDP1799oiGXqE_A',
#   'alias': 'mod-pizza-willow-grove',
#   'name': 'MOD Pizza',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RmpzEFq-pLPKxR4oCAU9bA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/mod-pizza-willow-grove?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 121,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.1563715, 'longitude': -75.1411307},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '4025 Welsh Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Willow Grove',
#    'zip_code': '19090',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['4025 Welsh Rd', 'Willow Grove, PA 19090']},
#   'phone': '+12679482180',
#   'display_phone': '(267) 948-2180',
#   'distance': 2882.1744944200564},
#  {'id': 'sNOzfwyTZDwKtMiTwjQobA',
#   'alias': 'vintage-bar-and-grill-abington',
#   'name': 'Vintage Bar and Grill',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/60hMGwGMb8s8ooTWGxybMQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/vintage-bar-and-grill-abington?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 118,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#    {'alias': 'sportsbars', 'title': 'Sports Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.11533, 'longitude': -75.12202},
#   'transactions': ['pickup'],
#   'price': '$$',
#   'location': {'address1': '1116 Old York Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Abington',
#    'zip_code': '19001',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1116 Old York Rd', 'Abington, PA 19001']},
#   'phone': '+12158878500',
#   'display_phone': '(215) 887-8500',
#   'distance': 4792.820938635727},
#  {'id': 'VeI2ipPWyFCsUMU_fnP8qQ',
#   'alias': 'roberts-block-restaurant-and-bar-glenside',
#   'name': 'Roberts Block Restaurant & Bar',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LeRu5bBskTIcaoeEN6sVeg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/roberts-block-restaurant-and-bar-glenside?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 117,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'seafood', 'title': 'Seafood'},
#    {'alias': 'burgers', 'title': 'Burgers'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.1018294082948,
#    'longitude': -75.1532854141859},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2 Roberts Block',
#    'address2': '',
#    'address3': 'Glenside Train Station',
#    'city': 'Glenside',
#    'zip_code': '19038',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['2 Roberts Block',
#     'Glenside Train Station',
#     'Glenside, PA 19038']},
#   'phone': '+12156904445',
#   'display_phone': '(215) 690-4445',
#   'distance': 4433.447025908574},
#  {'id': 'W27TgjQ0XUaRH0qqxYv40g',
#   'alias': 'union-jacks-pub-glenside',
#   'name': "Union Jack's Pub",
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_bqNA0MZdbZfqRpHvIzLVw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/union-jacks-pub-glenside?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 115,
#   'categories': [{'alias': 'pubs', 'title': 'Pubs'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.1098799, 'longitude': -75.16518},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2750 Limekiln Pike',
#    'address2': '',
#    'address3': '',
#    'city': 'Glenside',
#    'zip_code': '19038',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['2750 Limekiln Pike', 'Glenside, PA 19038']},
#   'phone': '+12158866014',
#   'display_phone': '(215) 886-6014',
#   'distance': 3389.476319376059},
#  {'id': 'LCitqsu9DV1RjGn7EIzzIQ',
#   'alias': 'outback-steakhouse-jenkintown',
#   'name': 'Outback Steakhouse',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/UT7pqBELPXhLpEpm7wnbTQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/outback-steakhouse-jenkintown?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 110,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 40.10321, 'longitude': -75.1251599},
#   'transactions': ['delivery'],
#   'price': '$$',
#   'location': {'address1': '610 Old York Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Jenkintown',
#    'zip_code': '19046',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['610 Old York Rd', 'Jenkintown, PA 19046']},
#   'phone': '+12158865120',
#   'display_phone': '(215) 886-5120',
#   'distance': 5651.143198843318},
#  {'id': 'aRb_ToTRcHa9BICLLj8n-A',
#   'alias': 'pho-viet-hoa-willow-grove-2',
#   'name': 'Pho Viet Hoa',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/znj1cMitIOzALA2GEGA18w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pho-viet-hoa-willow-grove-2?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 110,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.1526768, 'longitude': -75.1362924},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '3646 Welsh Rd',
#    'address2': '',
#    'address3': None,
#    'city': 'Willow Grove',
#    'zip_code': '19090',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['3646 Welsh Rd', 'Willow Grove, PA 19090']},
#   'phone': '+12153462330',
#   'display_phone': '(215) 346-2330',
#   'distance': 2915.468114395583},
#  {'id': 'YvaccJaSqbCNOYsEqWBSCw',
#   'alias': 'banh-street-abington',
#   'name': 'Banh Street',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/RRMultJDFBjftHoNddfb4w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/banh-street-abington?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 107,
#   'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 40.12008, 'longitude': -75.13467},
#   'transactions': ['delivery'],
#   'price': '$',
#   'location': {'address1': '1062 Tyson Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Abington',
#    'zip_code': '19001',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1062 Tyson Ave', 'Abington, PA 19001']},
#   'phone': '+12676262698',
#   'display_phone': '(267) 626-2698',
#   'distance': 3584.2877859822456},
#  {'id': 'h82_S_QDq8V1htf30pZq2w',
#   'alias': 'scoogis-classic-italian-flourtown',
#   'name': 'Scoogis Classic Italian',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/b2Tt4rNykX5iX95MhtVD7g/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/scoogis-classic-italian-flourtown?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 104,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.1134910583496,
#    'longitude': -75.2141876220703},
#   'transactions': ['restaurant_reservation'],
#   'price': '$$',
#   'location': {'address1': '738 Bethlehem Pike',
#    'address2': '',
#    'address3': '',
#    'city': 'Flourtown',
#    'zip_code': '19031',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['738 Bethlehem Pike', 'Flourtown, PA 19031']},
#   'phone': '+12152331063',
#   'display_phone': '(215) 233-1063',
#   'distance': 4948.115687314113},
#  {'id': 'xQ6EVfXRofhPUCveg1m7Sg',
#   'alias': 'umami-umami-dresher',
#   'name': 'Umami Umami',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3s8_5HnCnTJvQNOQtAZFAQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/umami-umami-dresher?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 102,
#   'categories': [{'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.14187, 'longitude': -75.16658},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1708 Limekiln Pike',
#    'address2': '',
#    'address3': '',
#    'city': 'Dresher',
#    'zip_code': '19025',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1708 Limekiln Pike', 'Dresher, PA 19025']},
#   'phone': '+12155426993',
#   'display_phone': '(215) 542-6993',
#   'distance': 219.6814111624997},
#  {'id': 'jGgUfiMg0_a6ehbz_ucDkQ',
#   'alias': 'viet-thai-cuisine-horsham',
#   'name': 'Viet Thai Cuisine',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/laN5up_8dRsyGxaxaYaA7w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/viet-thai-cuisine-horsham?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 101,
#   'categories': [{'alias': 'thai', 'title': 'Thai'},
#    {'alias': 'vietnamese', 'title': 'Vietnamese'},
#    {'alias': 'soup', 'title': 'Soup'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.17287, 'longitude': -75.1276},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '160 Easton Rd',
#    'address2': None,
#    'address3': '',
#    'city': 'Horsham',
#    'zip_code': '19044',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['160 Easton Rd', 'Horsham, PA 19044']},
#   'phone': '+12154438885',
#   'display_phone': '(215) 443-8885',
#   'distance': 4994.760941201395},
#  {'id': 'Ko6WrkU-vUngOIJG_isrzA',
#   'alias': 'fireside-bar-and-grille-ambler',
#   'name': 'Fireside Bar & Grille',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/KmErbms-6G93-14pdUnXRw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/fireside-bar-and-grille-ambler?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 99,
#   'categories': [{'alias': 'desserts', 'title': 'Desserts'},
#    {'alias': 'diners', 'title': 'Diners'},
#    {'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.1582679748535,
#    'longitude': -75.2135696411133},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1211 S Bethlehem Pike',
#    'address2': '',
#    'address3': '',
#    'city': 'Ambler',
#    'zip_code': '19002',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1211 S Bethlehem Pike', 'Ambler, PA 19002']},
#   'phone': '+12156436540',
#   'display_phone': '(215) 643-6540',
#   'distance': 4399.37174455503},
#  {'id': 'OhTknUVRxFU8YbaiWZkG3w',
#   'alias': 'pizza-box-glenside',
#   'name': 'Pizza Box',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/yZPGeghIV5H3uAoG62KNaA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/pizza-box-glenside?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 94,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.1061885, 'longitude': -75.1643013},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '43 Limekiln Pike',
#    'address2': '',
#    'address3': '',
#    'city': 'Glenside',
#    'zip_code': '19038',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['43 Limekiln Pike', 'Glenside, PA 19038']},
#   'phone': '+12155765255',
#   'display_phone': '(215) 576-5255',
#   'distance': 3794.6245389536193},
#  {'id': '6F1ZGDCyPTpV77PKTh6fGA',
#   'alias': 'carrabbas-italian-grill-willow-grove-3',
#   'name': "Carrabba's Italian Grill",
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/iJWHJHom7zVpOktSiikcrQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/carrabbas-italian-grill-willow-grove-3?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 92,
#   'categories': [{'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'seafood', 'title': 'Seafood'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.16169, 'longitude': -75.12535},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2575 Maryland Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Willow Grove',
#    'zip_code': '19090',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['2575 Maryland Rd', 'Willow Grove, PA 19090']},
#   'phone': '+12156593950',
#   'display_phone': '(215) 659-3950',
#   'distance': 4310.941408780934},
#  {'id': 'fIxzyxcJZ2-04TZ68DkXtA',
#   'alias': 'sushi-house-jenkintown',
#   'name': 'Sushi House',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7rhVG8Ptmm5HnaxYNd_6eg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/sushi-house-jenkintown?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 91,
#   'categories': [{'alias': 'sushi', 'title': 'Sushi Bars'},
#    {'alias': 'japanese', 'title': 'Japanese'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 40.107511792406, 'longitude': -75.1172199199966},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1595 The Fairway',
#    'address2': '',
#    'address3': '',
#    'city': 'Jenkintown',
#    'zip_code': '19046',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1595 The Fairway', 'Jenkintown, PA 19046']},
#   'phone': '+12676365186',
#   'display_phone': '(267) 636-5186',
#   'distance': 5615.5474890642645},
#  {'id': 'G5jc1s3Nyp8vPIZ6D0cu1w',
#   'alias': 'tgi-fridays-willow-grove',
#   'name': 'TGI Fridays',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/nC3w94iIoWHPc-S8mqL1JA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tgi-fridays-willow-grove?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 89,
#   'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 40.14349, 'longitude': -75.1216},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '2500 W Moreland Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Willow Grove',
#    'zip_code': '19090',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['2500 W Moreland Rd', 'Willow Grove, PA 19090']},
#   'phone': '+12156571597',
#   'display_phone': '(215) 657-1597',
#   'distance': 3752.307569146568},
#  {'id': 'w4_14pVOLW2Tdm9LTczORg',
#   'alias': 'corner-bakery-cafe-horsham',
#   'name': 'Corner Bakery Cafe',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/8sEwD9EfYPNxKUA6KdxnUA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/corner-bakery-cafe-horsham?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 82,
#   'categories': [{'alias': 'bakeries', 'title': 'Bakeries'},
#    {'alias': 'cafes', 'title': 'Cafes'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.15887, 'longitude': -75.14433},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '100 Welsh Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Horsham',
#    'zip_code': '19044',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['100 Welsh Rd', 'Horsham, PA 19044']},
#   'phone': '+12156595126',
#   'display_phone': '(215) 659-5126',
#   'distance': 2846.324911475639},
#  {'id': 'xppn6ViiUkZT_K_OswcB7g',
#   'alias': 'tamarindos-restaurant-flourtown',
#   'name': 'Tamarindos Restaurant',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/TVFLyiheCRC0SYRY6e8NDA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/tamarindos-restaurant-flourtown?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 80,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.11419, 'longitude': -75.21416},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '726 Bethlehem Pike',
#    'address2': '',
#    'address3': '',
#    'city': 'Flourtown',
#    'zip_code': '19031',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['726 Bethlehem Pike', 'Flourtown, PA 19031']},
#   'phone': '+12156192390',
#   'display_phone': '(215) 619-2390',
#   'distance': 4917.7037528361},
#  {'id': 'DNjgxBAUdya4sIAvy15b8A',
#   'alias': 'jarrettown-hotel-italian-restaurant-dresher',
#   'name': 'Jarrettown Hotel Italian Restaurant',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7VZJPGy2EilgWagcuqMF3w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/jarrettown-hotel-italian-restaurant-dresher?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 79,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.1551791, 'longitude': -75.1755824},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '1425 Limekiln Pike',
#    'address2': '',
#    'address3': '',
#    'city': 'Dresher',
#    'zip_code': '19025',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1425 Limekiln Pike', 'Dresher, PA 19025']},
#   'phone': '+12156546880',
#   'display_phone': '(215) 654-6880',
#   'distance': 1795.6791122595332},
#  {'id': 'nXx6nOAqC0DqVCUObuUsMA',
#   'alias': 'lees-hoagie-house-abington',
#   'name': "Lee's Hoagie House",
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/t806PJyiuQGXVi6REz4hAA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/lees-hoagie-house-abington?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 79,
#   'categories': [{'alias': 'sandwiches', 'title': 'Sandwiches'},
#    {'alias': 'cheesesteaks', 'title': 'Cheesesteaks'},
#    {'alias': 'wraps', 'title': 'Wraps'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 40.13127, 'longitude': -75.11647},
#   'transactions': ['pickup', 'delivery'],
#   'price': '$',
#   'location': {'address1': '1656 Old York Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Abington',
#    'zip_code': '19001',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['1656 Old York Rd', 'Abington, PA 19001']},
#   'phone': '+12156593322',
#   'display_phone': '(215) 659-3322',
#   'distance': 4460.381237774335},
#  {'id': 'yfmh5pifOvdQBfsEUL86ww',
#   'alias': 'athena-restaurant-glenside',
#   'name': 'Athena Restaurant',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/L0XufHLiImE3LncmwO2pUg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/athena-restaurant-glenside?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 78,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'greek', 'title': 'Greek'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 40.10538, 'longitude': -75.14737},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '264 N Keswick Ave',
#    'address2': '',
#    'address3': '',
#    'city': 'Glenside',
#    'zip_code': '19038',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['264 N Keswick Ave', 'Glenside, PA 19038']},
#   'phone': '+12158841777',
#   'display_phone': '(215) 884-1777',
#   'distance': 4225.843238210099},
#  {'id': 'YHvJyyklyzsQhCnbJu7pFA',
#   'alias': 'ninos-pizzarama-willow-grove',
#   'name': "Nino's Pizzarama",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y8GmX-AdhZ0zlSkSTV3AuQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/ninos-pizzarama-willow-grove?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 78,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.17161, 'longitude': -75.1275},
#   'transactions': [],
#   'price': '$',
#   'location': {'address1': '2819 Easton Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Willow Grove',
#    'zip_code': '19090',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['2819 Easton Rd', 'Willow Grove, PA 19090']},
#   'phone': '+12156755222',
#   'display_phone': '(215) 675-5222',
#   'distance': 4877.997618129917},
#  {'id': 'FzlwYkW9HzZ2PFDxxpcfew',
#   'alias': 'trios-tomato-pie-glenside',
#   'name': 'Trios Tomato Pie',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/LOuyC3dxE4IHrvq_qIUxOA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/trios-tomato-pie-glenside?adjust_creative=ea2TodAq4YX-4W3lzSJrcA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=ea2TodAq4YX-4W3lzSJrcA',
#   'review_count': 77,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 40.1071853935719,
#    'longitude': -75.1472119241953},
#   'transactions': [],
#   'price': '$$',
#   'location': {'address1': '402 N Easton Rd',
#    'address2': '',
#    'address3': '',
#    'city': 'Glenside',
#    'zip_code': '19038',
#    'country': 'US',
#    'state': 'PA',
#    'display_address': ['402 N Easton Rd', 'Glenside, PA 19038']},
#   'phone': '+12152771254',
#   'display_phone': '(215) 277-1254',
#   'distance': 4048.8407457603475}]

# %%
ydf = pd.DataFrame(response['businesses'])

# %%
ydf.head()
# Out:
#                                  alias  \
# 0  mad-mex-willow-grove-willow-grove-2
# 1        cantina-feliz-fort-washington
# 2         ooka-restaurant-willow-grove
# 3                 kitchen-bar-abington
# 4  the-cheesecake-factory-willow-grove
#
#                                           categories  \
# 0  [{'alias': 'mexican', 'title': 'Mexican'}, {'a...
# 1         [{'alias': 'mexican', 'title': 'Mexican'}]
# 2  [{'alias': 'japanese', 'title': 'Japanese'}, {...
# 3  [{'alias': 'tradamerican', 'title': 'American ...
# 4  [{'alias': 'newamerican', 'title': 'American (...
#
#                                          coordinates   display_phone  \
# 0  {'latitude': 40.147965, 'longitude': -75.1282592}  (267) 495-5000
# 1   {'latitude': 40.136374, 'longitude': -75.213808}  (215) 646-1320
# 2     {'latitude': 40.15676, 'longitude': -75.12175}  (215) 659-7688
# 3  {'latitude': 40.1249122619629, 'longitude': -7...  (215) 576-9766
# 4  {'latitude': 40.1402781186111, 'longitude': -7...  (215) 659-0270
#
#       distance                      id  \
# 0  3454.414192  rAe-1HU5Z-DuUXEbzASXDA
# 1  3950.728609  w_B0phzyFXPmeiVlzQrq6A
# 2  4300.544616  2Q1R2OhBbAQ581vK_r7NhA
# 3  4562.159885  JmzNw0WCPmZPZdq5nx9brg
# 4  3589.628567  uP42QDUxC2lxz15BUDbFnA
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/Y5AKNV...      False
# 1  https://s3-media2.fl.yelpcdn.com/bphoto/eCg8z6...      False
# 2  https://s3-media1.fl.yelpcdn.com/bphoto/vlL1qC...      False
# 3  https://s3-media2.fl.yelpcdn.com/bphoto/PTtRRJ...      False
# 4  https://s3-media4.fl.yelpcdn.com/bphoto/g4RnPr...      False
#
#                                             location                    name  \
# 0  {'address1': '2862 W Moreland Rd', 'address2':...  Mad Mex - Willow Grove
# 1  {'address1': '424 S Bethlehem Pike', 'address2...           Cantina Feliz
# 2  {'address1': '1109 Easton Rd', 'address2': '',...         Ooka Restaurant
# 3  {'address1': '1482 Old York Rd', 'address2': '...             Kitchen Bar
# 4  {'address1': '2500 W Moreland Rd', 'address2':...  The Cheesecake Factory
#
#           phone price  rating  review_count  \
# 0  +12674955000    $$     3.0           363
# 1  +12156461320    $$     4.0           358
# 2  +12156597688    $$     4.0           333
# 3  +12155769766    $$     3.0           324
# 4  +12156590270    $$     3.0           290
#
#                          transactions  \
# 0                          [delivery]
# 1                                  []
# 2                                  []
# 3  [restaurant_reservation, delivery]
# 4                          [delivery]
#
#                                                  url
# 0  https://www.yelp.com/biz/mad-mex-willow-grove-...
# 1  https://www.yelp.com/biz/cantina-feliz-fort-wa...
# 2  https://www.yelp.com/biz/ooka-restaurant-willo...
# 3  https://www.yelp.com/biz/kitchen-bar-abington?...
# 4  https://www.yelp.com/biz/the-cheesecake-factor...

# %%
ydf.shape
# Out:
# (50, 16)

# %%
ydf.loc[0]['categories']
# Out:
# [{'alias': 'mexican', 'title': 'Mexican'},
#  {'alias': 'tex-mex', 'title': 'Tex-Mex'}]

# %%
ydf['location']
# Out:
# 0     {'address1': '2862 W Moreland Rd', 'address2':...
# 1     {'address1': '424 S Bethlehem Pike', 'address2...
# 2     {'address1': '1109 Easton Rd', 'address2': '',...
# 3     {'address1': '1482 Old York Rd', 'address2': '...
# 4     {'address1': '2500 W Moreland Rd', 'address2':...
# 5     {'address1': '444 S Bethlehem Pike', 'address2...
# 6     {'address1': '2402 Easton Rd', 'address2': '',...
# 7     {'address1': '1844 Bethlehem Pike', 'address2'...
# 8     {'address1': '391 Highland Ave', 'address2': '...
# 9     {'address1': '1000 Frankford Ave', 'address2':...
# 10    {'address1': '3 Easton Rd', 'address2': '', 'a...
# 11    {'address1': '277 N Keswick Ave', 'address2': ...
# 12    {'address1': '1301 Old York Rd', 'address2': '...
# 13    {'address1': '2300 Easton Rd', 'address2': '',...
# 14    {'address1': '4001 Welsh Rd', 'address2': None...
# 15    {'address1': '233 Easton Rd', 'address2': '', ...
# 16    {'address1': '1015 Easton Rd', 'address2': '',...
# 17    {'address1': '100 Welsh Rd', 'address2': '', '...
# 18    {'address1': '278 Easton Rd', 'address2': '', ...
# 19    {'address1': '582 S Bethlehem Pike', 'address2...
# 20    {'address1': '256 N Keswick Ave', 'address2': ...
# 21    {'address1': '816 Old York Rd', 'address2': ''...
# 22    {'address1': '1533 Old York Rd', 'address2': '...
# 23    {'address1': '3945 Welsh Rd', 'address2': None...
# 24    {'address1': '294 N Keswick Ave', 'address2': ...
# 25    {'address1': '1170 Easton Rd', 'address2': '',...
# 26    {'address1': '2328 W Moreland Rd', 'address2':...
# 27    {'address1': '2720 Easton Rd', 'address2': Non...
# 28    {'address1': '4025 Welsh Rd', 'address2': '', ...
# 29    {'address1': '1116 Old York Rd', 'address2': '...
# 30    {'address1': '2 Roberts Block', 'address2': ''...
# 31    {'address1': '2750 Limekiln Pike', 'address2':...
# 32    {'address1': '610 Old York Rd', 'address2': ''...
# 33    {'address1': '3646 Welsh Rd', 'address2': '', ...
# 34    {'address1': '1062 Tyson Ave', 'address2': '',...
# 35    {'address1': '738 Bethlehem Pike', 'address2':...
# 36    {'address1': '1708 Limekiln Pike', 'address2':...
# 37    {'address1': '160 Easton Rd', 'address2': None...
# 38    {'address1': '1211 S Bethlehem Pike', 'address...
# 39    {'address1': '43 Limekiln Pike', 'address2': '...
# 40    {'address1': '2575 Maryland Rd', 'address2': '...
# 41    {'address1': '1595 The Fairway', 'address2': '...
# 42    {'address1': '2500 W Moreland Rd', 'address2':...
# 43    {'address1': '100 Welsh Rd', 'address2': '', '...
# 44    {'address1': '726 Bethlehem Pike', 'address2':...
# 45    {'address1': '1425 Limekiln Pike', 'address2':...
# 46    {'address1': '1656 Old York Rd', 'address2': '...
# 47    {'address1': '264 N Keswick Ave', 'address2': ...
# 48    {'address1': '2819 Easton Rd', 'address2': '',...
# 49    {'address1': '402 N Easton Rd', 'address2': ''...
# Name: location, dtype: object

# %% [markdown]
# `YelpAPI.search_query` arguments:
# - `location`
# - `sort_by`
# - `limit`
# - `offset`
# - `categories` *comma-separated list*
#
# Category dictionary: https://www.yelp.com/developers/documentation/v3/all_category_list

# %%
with open('./categories.json', encoding='utf-8') as json_file:
    categories = json.load(json_file)

# %%
categories
# Out:
# [{'alias': '3dprinting', 'title': '3D Printing', 'parents': ['localservices']},
#  {'alias': 'abruzzese',
#   'title': 'Abruzzese',
#   'parents': ['italian'],
#   'country_whitelist': ['IT']},
#  {'alias': 'absinthebars',
#   'title': 'Absinthe Bars',
#   'parents': ['bars'],
#   'country_whitelist': ['CZ']},
#  {'alias': 'acaibowls',
#   'title': 'Acai Bowls',
#   'parents': ['food'],
#   'country_blacklist': ['PL', 'MX', 'TR', 'CL', 'IT', 'AR']},
#  {'alias': 'accessories', 'title': 'Accessories', 'parents': ['fashion']},
#  {'alias': 'accountants', 'title': 'Accountants', 'parents': ['professional']},
#  {'alias': 'acnetreatment',
#   'title': 'Acne Treatment',
#   'parents': ['beautysvc']},
#  {'alias': 'active', 'title': 'Active Life', 'parents': []},
#  {'alias': 'acupuncture', 'title': 'Acupuncture', 'parents': ['health']},
#  {'alias': 'addictionmedicine',
#   'title': 'Addiction Medicine',
#   'parents': ['physicians'],
#   'country_blacklist': ['JP']},
#  {'alias': 'adoptionservices',
#   'title': 'Adoption Services',
#   'parents': ['localservices']},
#  {'alias': 'adult', 'title': 'Adult', 'parents': ['shopping']},
#  {'alias': 'adultedu', 'title': 'Adult Education', 'parents': ['education']},
#  {'alias': 'adultentertainment',
#   'title': 'Adult Entertainment',
#   'parents': ['nightlife']},
#  {'alias': 'advertising', 'title': 'Advertising', 'parents': ['professional']},
#  {'alias': 'aerialfitness', 'title': 'Aerial Fitness', 'parents': ['fitness']},
#  {'alias': 'aerialtours', 'title': 'Aerial Tours', 'parents': ['tours']},
#  {'alias': 'aestheticians',
#   'title': 'Aestheticians',
#   'parents': ['medicalspa'],
#   'country_blacklist': ['MX', 'CL', 'AR']},
#  {'alias': 'afghani',
#   'title': 'Afghan',
#   'parents': ['restaurants'],
#   'country_blacklist': ['MX', 'TR']},
#  {'alias': 'african',
#   'title': 'African',
#   'parents': ['restaurants'],
#   'country_blacklist': ['TR']},
#  {'alias': 'afrobrazilian',
#   'title': 'Afro-Brazilian',
#   'parents': ['religiousorgs'],
#   'country_whitelist': ['BR']},
#  {'alias': 'agriturismi',
#   'title': 'Agriturismi',
#   'parents': ['hotels'],
#   'country_whitelist': ['DE',
#    'PL',
#    'MX',
#    'AT',
#    'FR',
#    'ES',
#    'CH',
#    'CL',
#    'CZ',
#    'IT',
#    'TW',
#    'AR']},
#  {'alias': 'aircraftdealers',
#   'title': 'Aircraft Dealers',
#   'parents': ['auto'],
#   'country_whitelist': ['US', 'PT', 'CZ']},
#  {'alias': 'aircraftrepairs',
#   'title': 'Aircraft Repairs',
#   'parents': ['auto']},
#  {'alias': 'airductcleaning',
#   'title': 'Air Duct Cleaning',
#   'parents': ['localservices'],
#   'country_whitelist': ['MY',
#    'AU',
#    'US',
#    'SG',
#    'NZ',
#    'PH',
#    'ES',
#    'CA',
#    'IE',
#    'GB',
#    'IT']},
#  {'alias': 'airlines', 'title': 'Airlines', 'parents': ['transport']},
#  {'alias': 'airport_shuttles',
#   'title': 'Airport Shuttles',
#   'parents': ['transport']},
#  {'alias': 'airportlounges', 'title': 'Airport Lounges', 'parents': ['bars']},
#  {'alias': 'airports', 'title': 'Airports', 'parents': ['hotelstravel']},
#  {'alias': 'airportterminals',
#   'title': 'Airport Terminals',
#   'parents': ['airports']},
#  {'alias': 'airsoft', 'title': 'Airsoft', 'parents': ['active']},
#  {'alias': 'alentejo',
#   'title': 'Alentejo',
#   'parents': ['portuguese'],
#   'country_whitelist': ['PT']},
#  {'alias': 'algarve',
#   'title': 'Algarve',
#   'parents': ['portuguese'],
#   'country_whitelist': ['PT']},
#  {'alias': 'allergist', 'title': 'Allergists', 'parents': ['physicians']},
#  {'alias': 'alsatian',
#   'title': 'Alsatian',
#   'parents': ['french'],
#   'country_whitelist': ['FR', 'DE']},
#  {'alias': 'alternativemedicine',
#   'title': 'Alternative Medicine',
#   'parents': ['health'],
#   'country_blacklist': ['DE',
#    'PT',
#    'PH',
#    'ES',
#    'TR',
#    'AR',
#    'MY',
#    'HK',
#    'PL',
#    'MX',
#    'AT',
#    'JP',
#    'FI',
#    'CH',
#    'CL',
#    'TW']},
#  {'alias': 'altoatesine',
#   'title': 'Altoatesine',
#   'parents': ['italian'],
#   'country_whitelist': ['IT']},
#  {'alias': 'amateursportsteams',
#   'title': 'Amateur Sports Teams',
#   'parents': ['active'],
#   'country_blacklist': ['CZ']},
#  {'alias': 'amusementparks',
#   'title': 'Amusement Parks',
#   'parents': ['active']},
#  {'alias': 'andalusian',
#   'title': 'Andalusian',
#   'parents': ['restaurants'],
#   'country_whitelist': ['IT', 'ES']},
#  {'alias': 'anesthesiologists',
#   'title': 'Anesthesiologists',
#   'parents': ['physicians'],
#   'country_whitelist': ['SE', 'AU', 'US', 'PT', 'BE', 'IT', 'FR']},
#  {'alias': 'animalassistedtherapy',
#   'title': 'Animal Assisted Therapy',
#   'parents': ['health']},
#  {'alias': 'animalholistic',
#   'title': 'Holistic Animal Care',
#   'parents': ['petservices']},
#  {'alias': 'animalphysicaltherapy',
#   'title': 'Animal Physical Therapy',
#   'parents': ['petservices']},
#  {'alias': 'animalshelters', 'title': 'Animal Shelters', 'parents': ['pets']},
#  {'alias': 'antiques', 'title': 'Antiques', 'parents': ['shopping']},
#  {'alias': 'apartmentagents',
#   'title': 'Apartment Agents',
#   'parents': ['realestateagents']},
#  {'alias': 'apartments', 'title': 'Apartments', 'parents': ['realestate']},
#  {'alias': 'appliances', 'title': 'Appliances', 'parents': ['homeandgarden']},
#  {'alias': 'appraisalservices',
#   'title': 'Appraisal Services',
#   'parents': ['localservices']},
#  {'alias': 'apulian',
#   'title': 'Apulian',
#   'parents': ['italian'],
#   'country_whitelist': ['IT', 'FR']},
#  {'alias': 'aquariums', 'title': 'Aquariums', 'parents': ['active']},
#  {'alias': 'aquariumservices',
#   'title': 'Aquarium Services',
#   'parents': ['petservices'],
#   'country_blacklist': ['HK', 'MX', 'JP', 'CL', 'AR']},
#  {'alias': 'arabian',
#   'title': 'Arabian',
#   'parents': ['restaurants'],
#   'country_blacklist': ['DK']},
#  {'alias': 'arabpizza',
#   'title': 'Arab Pizza',
#   'parents': ['arabian'],
#   'country_whitelist': ['BR']},
#  {'alias': 'arcades', 'title': 'Arcades', 'parents': ['arts']},
#  {'alias': 'archery', 'title': 'Archery', 'parents': ['active']},
#  {'alias': 'architects', 'title': 'Architects', 'parents': ['professional']},
#  {'alias': 'architecturaltours',
#   'title': 'Architectural Tours',
#   'parents': ['tours']},
#  {'alias': 'argentine',
#   'title': 'Argentine',
#   'parents': ['restaurants'],
#   'country_blacklist': ['FI']},
#  {'alias': 'armenian',
#   'title': 'Armenian',
#   'parents': ['restaurants'],
#   'country_whitelist': ['PL',
#    'US',
#    'BE',
#    'FR',
#    'ES',
#    'TR',
#    'CZ',
#    'GB',
#    'IT',
#    'AR']},
#  {'alias': 'arroceria_paella',
#   'title': 'Arroceria / Paella',
#   'parents': ['spanish'],
#   'country_whitelist': ['ES']},
#  {'alias': 'artclasses',
#   'title': 'Art Classes',
#   'parents': ['education'],
#   'country_blacklist': ['HK', 'MX', 'JP', 'CL', 'AR']},
#  {'alias': 'artificialturf',
#   'title': 'Artificial Turf',
#   'parents': ['homeservices']},
#  {'alias': 'artmuseums',
#   'title': 'Art Museums',
#   'parents': ['museums'],
#   'country_blacklist': ['FR']},
#  {'alias': 'artrestoration',
#   'title': 'Art Restoration',
#   'parents': ['localservices']},
#  {'alias': 'arts', 'title': 'Arts & Entertainment', 'parents': []},
#  {'alias': 'artsandcrafts', 'title': 'Arts & Crafts', 'parents': ['shopping']},
#  {'alias': 'artschools',
#   'title': 'Art Schools',
#   'parents': ['specialtyschools']},
#  {'alias': 'artspacerentals',
#   'title': 'Art Space Rentals',
#   'parents': ['realestate'],
#   'country_whitelist': ['HK', 'IT', 'SG', 'SE', 'IE', 'JP', 'GB', 'US']},
#  {'alias': 'artsupplies',
#   'title': 'Art Supplies',
#   'parents': ['artsandcrafts']},
#  {'alias': 'arttours', 'title': 'Art Tours', 'parents': ['tours']},
#  {'alias': 'asianfusion', 'title': 'Asian Fusion', 'parents': ['restaurants']},
#  {'alias': 'assistedliving',
#   'title': 'Assisted Living Facilities',
#   'parents': ['health']},
#  {'alias': 'astrologers',
#   'title': 'Astrologers',
#   'parents': ['psychic_astrology']},
#  {'alias': 'asturian',
#   'title': 'Asturian',
#   'parents': ['restaurants'],
#   'country_whitelist': ['ES']},
#  {'alias': 'ateliers',
#   'title': 'Ateliers',
#   'parents': ['artsandcrafts'],
#   'country_whitelist': ['DE',
#    'NL',
#    'BE',
#    'AT',
#    'NO',
#    'DK',
#    'JP',
#    'TR',
#    'CH',
#    'IT']},
#  {'alias': 'attractionfarms',
#   'title': 'Attraction Farms',
#   'parents': ['farms'],
#   'country_whitelist': ['DE',
#    'IT',
#    'PT',
#    'BR',
#    'AT',
#    'ES',
#    'NO',
#    'SE',
#    'DK',
#    'CH',
#    'US']},
#  {'alias': 'atvrentals',
#   'title': 'ATV Rentals/Tours',
#   'parents': ['active'],
#   'country_whitelist': ['SE', 'FI', 'NL', 'BE', 'US', 'NO']},
#  {'alias': 'auctionhouses',
#   'title': 'Auction Houses',
#   'parents': ['shopping'],
#   'country_blacklist': ['MY', 'HK', 'PH', 'JP', 'TR', 'CL', 'TW', 'AR']},
#  {'alias': 'audiologist',
#   'title': 'Audiologist',
#   'parents': ['physicians'],
#   'country_blacklist': ['CH', 'AT', 'CZ', 'DE']},
#  {'alias': 'audiovisualequipmentrental',
#   'title': 'Audio/Visual Equipment Rental',
#   'parents': ['partyequipmentrentals'],
#   'country_whitelist': ['DE',
#    'BR',
#    'NL',
#    'BE',
#    'AT',
#    'FR',
#    'ES',
#    'NO',
#    'SE',
#    'DK',
#    'CH',
#    'US']},
#  {'alias': 'australian', 'title': 'Australian', 'parents': ['restaurants']},
#  {'alias': 'austrian',
#   'title': 'Austrian',
#   'parents': ['restaurants'],
#   'country_blacklist': ['ES', 'DK']},
#  {'alias': 'authorized_postal_representative',
#   'title': 'Authorized Postal Representative',
#   'parents': ['publicservicesgovt'],
#   'country_whitelist': ['SE', 'NO']},
#  {'alias': 'auto', 'title': 'Automotive', 'parents': []},
#  {'alias': 'auto_detailing',
#   'title': 'Auto Detailing',
#   'parents': ['auto'],
#   'country_blacklist': ['AU', 'BR', 'ES']},
#  {'alias': 'autocustomization',
#   'title': 'Auto Customization',
#   'parents': ['auto'],
#   'country_whitelist': ['MX', 'PT', 'SG', 'ES', 'CL', 'CZ', 'US', 'AR']},
#  {'alias': 'autodamageassessment',
#   'title': 'Car Inspectors',
#   'parents': ['auto'],
#   'country_whitelist': ['DE', 'PT', 'BR', 'NL', 'BE', 'NO', 'SE', 'DK', 'US']},
#  {'alias': 'autoelectric',
#   'title': 'Auto Electric Services',
#   'parents': ['auto'],
#   'country_whitelist': ['MX', 'PT', 'BR', 'ES', 'CL', 'CZ', 'IT', 'AR']},
#  {'alias': 'autoglass',
#   'title': 'Auto Glass Services',
#   'parents': ['auto'],
#   'country_blacklist': ['ES']},
#  {'alias': 'autoinsurance',
#   'title': 'Auto Insurance',
#   'parents': ['insurance'],
#   'country_blacklist': ['MY',
#    'HK',
#    'DE',
#    'SG',
#    'NZ',
#    'PH',
#    'AT',
#    'FR',
#    'CA',
#    'IE',
#    'FI',
#    'CH',
#    'GB',
#    'TW']},
#  {'alias': 'autoloanproviders',
#   'title': 'Auto Loan Providers',
#   'parents': ['auto'],
#   'country_whitelist': ['AU', 'IT', 'PT', 'SG', 'CA', 'TR', 'CZ', 'US']},
#  {'alias': 'autopartssupplies',
#   'title': 'Auto Parts & Supplies',
#   'parents': ['auto']},
#  {'alias': 'autorepair', 'title': 'Auto Repair', 'parents': ['auto']},
#  {'alias': 'autosecurity',
#   'title': 'Auto Security',
#   'parents': ['auto'],
#   'country_blacklist': ['FR']},
#  {'alias': 'autoupholstery', 'title': 'Auto Upholstery', 'parents': ['auto']},
#  {'alias': 'auvergnat',
#   'title': 'Auvergnat',
#   'parents': ['french'],
#   'country_whitelist': ['FR']},
#  {'alias': 'aviationservices',
#   'title': 'Aviation Services',
#   'parents': ['auto']},
#  {'alias': 'awnings', 'title': 'Awnings', 'parents': ['localservices']},
#  {'alias': 'axethrowing',
#   'title': 'Axe Throwing',
#   'parents': ['active'],
#   'country_whitelist': ['US', 'CA', 'GB']},
#  {'alias': 'ayurveda', 'title': 'Ayurveda', 'parents': ['health']},
#  {'alias': 'azores',
#   'title': 'Azores',
#   'parents': ['portuguese'],
#   'country_whitelist': ['PT']},
#  {'alias': 'baby_gear',
#   'title': 'Baby Gear & Furniture',
#   'parents': ['shopping']},
#  {'alias': 'backflowservices',
#   'title': 'Backflow Services',
#   'parents': ['plumbing'],
#   'country_whitelist': ['US']},
#  {'alias': 'backshop',
#   'title': 'Backshop',
#   'parents': ['food'],
#   'country_whitelist': ['CH', 'AT', 'DE']},
#  {'alias': 'baden',
#   'title': 'Baden',
#   'parents': ['german'],
#   'country_whitelist': ['DE']},
#  {'alias': 'badminton',
#   'title': 'Badminton',
#   'parents': ['active'],
#   'country_blacklist': ['PL', 'BR', 'SG', 'NZ']},
#  {'alias': 'bagels',
#   'title': 'Bagels',
#   'parents': ['food'],
#   'country_blacklist': ['AU', 'ES']},
#  {'alias': 'baguettes',
#   'title': 'Baguettes',
#   'parents': ['restaurants'],
#   'country_whitelist': ['DE', 'MX', 'PT', 'NO', 'SE', 'TR', 'CZ', 'IT']},
#  {'alias': 'bailbondsmen',
#   'title': 'Bail Bondsmen',
#   'parents': ['localservices'],
#   'country_whitelist': ['PT', 'US']},
#  {'alias': 'bakeries', 'title': 'Bakeries', 'parents': ['food']},
#  {'alias': 'balloonservices',
#   'title': 'Balloon Services',
#   'parents': ['eventservices'],
#   'country_whitelist': ['AU',
#    'DE',
#    'PL',
#    'BR',
#    'SG',
#    'NL',
#    'NZ',
#    'AT',
#    'BE',
#    'CA',
#    'IE',
#    'CH',
#    'GB',
#    'US']},
#  {'alias': 'bangladeshi',
#   'title': 'Bangladeshi',
#   'parents': ['restaurants'],
#   'country_blacklist': ['DK', 'MX', 'PT', 'TR', 'ES']},
#  {'alias': 'bankruptcy', 'title': 'Bankruptcy Law', 'parents': ['lawyers']},
#  {'alias': 'banks',
#   'title': 'Banks & Credit Unions',
#   'parents': ['financialservices']},
#  {'alias': 'barbers', 'title': 'Barbers', 'parents': ['beautysvc']},
#  {'alias': 'barcrawl',
#   'title': 'Bar Crawl',
#   'parents': ['nightlife'],
#   'country_whitelist': ['AU', 'DE', 'PL', 'MX', 'AT', 'CH', 'CZ', 'US', 'AR']},
#  {'alias': 'barreclasses',
#   'title': 'Barre Classes',
#   'parents': ['fitness'],
#   'country_whitelist': ['AU',
#    'PT',
#    'NL',
#    'NZ',
#    'BE',
#    'CA',
#    'NO',
#    'IE',
#    'DK',
#    'FI',
#    'CZ',
#    'GB',
#    'US']},
#  {'alias': 'bars', 'title': 'Bars', 'parents': ['nightlife']},
#  {'alias': 'bartenders',
#   'title': 'Bartenders',
#   'parents': ['eventservices'],
#   'country_blacklist': ['MY',
#    'HK',
#    'PL',
#    'SG',
#    'NZ',
#    'PH',
#    'AT',
#    'NO',
#    'IE',
#    'JP',
#    'FI',
#    'TR',
#    'CH',
#    'GB',
#    'TW']},
#  {'alias': 'bartendingschools',
#   'title': 'Bartending Schools',
#   'parents': ['specialtyschools']},
#  {'alias': 'baseballfields',
#   'title': 'Baseball Fields',
#   'parents': ['active'],
#   'country_blacklist': ['FR']},
#  {'alias': 'basketballcourts',
#   'title': 'Basketball Courts',
#   'parents': ['active'],
#   'country_blacklist': ['SE', 'IE', 'PL', 'BR', 'NL', 'GB', 'CA']},
#  {'alias': 'basque',
#   'title': 'Basque',
#   'parents': ['restaurants'],
#   'country_blacklist': ['AU', 'DK', 'PT', 'SG', 'TR', 'CZ']},
#  {'alias': 'bathing_area',
#   'title': 'Bathing Area',
#   'parents': ['active'],
#   'country_whitelist': ['DE',
#    'PT',
#    'AT',
#    'NO',
#    'SE',
#    'DK',
#    'JP',
#    'FI',
#    'CH',
#    'CZ']},
#  {'alias': 'batterystores',
#   'title': 'Battery Stores',
#   'parents': ['shopping'],
#   'country_blacklist': ['CZ']},
#  {'alias': 'battingcages',
#   'title': 'Batting Cages',
#   'parents': ['active'],
#   'country_whitelist': ['TW', 'JP', 'US', 'SG']},
#  {'alias': 'bavarian',
#   'title': 'Bavarian',
#   'parents': ['restaurants'],
#   'country_whitelist': ['CH', 'AT', 'DE']},
#  {'alias': 'bbq',
#   'title': 'Barbeque',
#   'parents': ['restaurants'],
#   'country_blacklist': ['AU', 'BR']},
#  {'alias': 'beachbars',
#   'title': 'Beach Bars',
#   'parents': ['bars'],
#   'country_blacklist': ['MY',
#    'HK',
#    'PL',
#    'NZ',
#    'PH',
#    'BE',
#    'CA',
#    'IE',
#    'JP',
#    'FI',
#    'TR',
#    'CZ',
#    'GB',
#    'US',
#    'TW']},
#  {'alias': 'beachequipmentrental',
#   'title': 'Beach Equipment Rentals',
#   'parents': ['active']},
#  {'alias': 'beaches', 'title': 'Beaches', 'parents': ['active']},
#  {'alias': 'beachvolleyball',
#   'title': 'Beach Volleyball',
#   'parents': ['active'],
#   'country_blacklist': ['NL',
#    'NZ',
#    'PH',
#    'FR',
#    'CA',
#    'IE',
#    'TR',
#    'IT',
#    'MY',
#    'HK',
#    'PL',
#    'BE',
#    'CH',
#    'GB',
#    'US',
#    'TW']},
#  {'alias': 'beautysvc', 'title': 'Beauty & Spas', 'parents': []},
#  {'alias': 'bedbreakfast',
#   'title': 'Bed & Breakfast',
#   'parents': ['hotelstravel'],
#   'country_blacklist': ['SG']},
#  {'alias': 'beer_and_wine',
#   'title': 'Beer, Wine & Spirits',
#   'parents': ['food']},
#  {'alias': 'beerbar', 'title': 'Beer Bar', 'parents': ['bars']},
#  {'alias': 'beergarden',
#   'title': 'Beer Garden',
#   'parents': ['restaurants'],
#   'country_whitelist': ['CH', 'AT', 'CZ', 'DE']},
#  {'alias': 'beergardens',
#   'title': 'Beer Gardens',
#   'parents': ['nightlife'],
#   'country_whitelist': ['AU',
#    'PL',
#    'MX',
#    'US',
#    'NO',
#    'FR',
#    'SE',
#    'IE',
#    'DK',
#    'JP',
#    'CZ',
#    'GB',
#    'IT']},
#  {'alias': 'beerhall',
#   'title': 'Beer Hall',
#   'parents': ['restaurants'],
#   'country_whitelist': ['CH', 'AT', 'DE']},
#  {'alias': 'beertours', 'title': 'Beer Tours', 'parents': ['tours']},
#  {'alias': 'behavioranalysts',
#   'title': 'Behavior Analysts',
#   'parents': ['health']},
#  {'alias': 'beira',
#   'title': 'Beira',
#   'parents': ['portuguese'],
#   'country_whitelist': ['PT']},
#  {'alias': 'beisl',
#   'title': 'Beisl',
#   'parents': ['restaurants'],
#   'country_whitelist': ['AT']},
#  {'alias': 'belgian', 'title': 'Belgian', 'parents': ['restaurants']},
#  {'alias': 'bento',
#   'title': 'Bento',
#   'parents': ['food'],
#   'country_whitelist': ['JP']},
#  {'alias': 'berrichon',
#   'title': 'Berrichon',
#   'parents': ['french'],
#   'country_whitelist': ['FR']},
#  {'alias': 'bespoke',
#   'title': 'Bespoke Clothing',
#   'parents': ['shopping'],
#   'country_blacklist': ['MX', 'BR', 'SE', 'JP', 'FI', 'TR', 'CL', 'AR']},
#  {'alias': 'bettingcenters',
#   'title': 'Betting Centers',
#   'parents': ['arts'],
#   'country_blacklist': ['FI', 'SG', 'FR', 'NZ', 'CA', 'US', 'NO']},
#  {'alias': 'beverage_stores',
#   'title': 'Beverage Store',
#   'parents': ['food'],
#   'country_whitelist': ['AU',
#    'DE',
#    'IT',
#    'PT',
#    'NL',
#    'BE',
#    'AT',
#    'ES',
#    'TR',
#    'CH',
#    'CL',
#    'US']},
#  {'alias': 'bicyclepaths',
#   'title': 'Bicycle Paths',
#   'parents': ['active'],
#   'country_blacklist': ['MY',
#    'HK',
#    'DE',
#    'IT',
#    'PH',
#    'AT',
#    'FR',
#    'CA',
#    'TR',
#    'CH',
#    'US',
#    'TW']},
#  {'alias': 'bicycles',
#   'title': 'Bicycles',
#   'parents': [],
#   'country_whitelist': ['PL', 'PT', 'CZ', 'DK']},
#  {'alias': 'bike_repair_maintenance',
#   'title': 'Bike Repair/Maintenance',
#   'parents': ['localservices']},
#  {'alias': 'bikeassociations',
#   'title': 'Bike Associations',
#   'parents': ['bicycles'],
#   'country_whitelist': ['PT', 'DK']},
#  {'alias': 'bikeparking',
#   'title': 'Bike Parking',
#   'parents': ['active'],
#   'country_blacklist': ['FR']},
#  {'alias': 'bikerentals', 'title': 'Bike Rentals', 'parents': ['active']},
#  {'alias': 'bikerepair',
#   'title': 'Bike Repair',
#   'parents': ['bicycles'],
#   'country_whitelist': ['PT', 'DK']},
#  {'alias': 'bikes', 'title': 'Bikes', 'parents': ['sportgoods']},
#  {'alias': 'bikesharing', 'title': 'Bike Sharing', 'parents': ['transport']},
#  {'alias': 'bikeshop',
#   'title': 'Bike Shop',
#   'parents': ['bicycles'],
#   'country_whitelist': ['PT', 'DK']},
#  {'alias': 'biketours', 'title': 'Bike tours', 'parents': ['tours']},
#  {'alias': 'billingservices',
#   'title': 'Billing Services',
#   'parents': ['professional'],
#   'country_whitelist': ['SE', 'US']},
#  {'alias': 'bingo',
#   'title': 'Bingo Halls',
#   'parents': ['arts'],
#   'country_whitelist': ['AU',
#    'IT',
#    'MX',
#    'BR',
#    'NZ',
#    'NO',
#    'ES',
#    'SE',
#    'IE',
#    'DK',
#    'FI',
#    'CL',
#    'GB',
#    'US',
#    'AR']},
#  {'alias': 'birdshops',
#   'title': 'Bird Shops',
#   'parents': ['petstore'],
#   'country_whitelist': ['DE',
#    'IT',
#    'SG',
#    'NL',
#    'BE',
#    'ES',
#    'NO',
#    'SE',
#    'DK',
#    'US']},
#  {'alias': 'bistros',
#   'title': 'Bistros',
#   'parents': ['restaurants'],
#   'country_blacklist': ['US']},
#  {'alias': 'blacksea',
#   'title': 'Black Sea',
#   'parents': ['restaurants'],
#   'country_whitelist': ['TR']},
#  {'alias': 'blinds', 'title': 'Shades & Blinds', 'parents': ['homeservices']},
#  {'alias': 'blooddonation',
#   'title': 'Blood & Plasma Donation Centers',
#   'parents': ['health'],
#   'country_blacklist': ['MY',
#    'HK',
#    'SG',
#    'NL',
#    'PH',
#    'BE',
#    'CA',
#    'IE',
#    'FI',
#    'GB',
#    'TW']},
#  {'alias': 'blowfish',
#   'title': 'Blowfish',
#   'parents': ['japanese'],
#   'country_whitelist': ['JP']},
#  {'alias': 'blowoutservices',
#   'title': 'Blow Dry/Out Services',
#   'parents': ['hair'],
#   'country_whitelist': ['AU',
#    'PT',
#    'CA',
#    'FR',
#    'NO',
#    'IE',
#    'DK',
#    'TR',
#    'CZ',
#    'GB',
#    'US']},
#  {'alias': 'boatcharters',
#   'title': 'Boat Charters',
#   'parents': ['eventservices'],
#   'country_blacklist': ['CZ']},
#  {'alias': 'boatdealers',
#   'title': 'Boat Dealers',
#   'parents': ['auto'],
#   'country_blacklist': ['MY',
#    'HK',
#    'BR',
#    'PH',
#    'AT',
#    'FR',
#    'JP',
#    'FI',
#    'TR',
#    'CH',
#    'CL',
#    'IT',
#    'TW']},
#  {'alias': 'boating', 'title': 'Boating', 'parents': ['active']},
#  {'alias': 'boatpartsandsupplies',
#   'title': 'Boat Parts & Supplies',
#   'parents': ['auto']},
#  {'alias': 'boatrepair',
#   'title': 'Boat Repair',
#   'parents': ['professional'],
#   'country_blacklist': ['CZ']},
#  {'alias': 'boattours', 'title': 'Boat Tours', 'parents': ['tours']},
#  {'alias': 'bobsledding', 'title': 'Bobsledding', 'parents': ['active']},
#  {'alias': 'bocceball', 'title': 'Bocce Ball', 'parents': ['active']},
#  {'alias': 'bodycontouring',
#   'title': 'Body Contouring',
#   'parents': ['health'],
#   'country_blacklist': ['IT', 'FR']},
#  {'alias': 'bodyshops', 'title': 'Body Shops', 'parents': ['auto']},
#  {'alias': 'bookbinding',
#   'title': 'Bookbinding',
#   'parents': ['localservices']},
#  {'alias': 'bookkeepers',
#   'title': 'Bookkeepers',
#   'parents': ['professional'],
#   'country_whitelist': ['MY',
#    'HK',
#    'AU',
#    'US',
#    'SG',
#    'NL',
#    'NZ',
#    'PH',
#    'BE',
#    'CA',
#    'IE',
#    'GB',
#    'CZ',
#    'TW']},
#  {'alias': 'bookstores', 'title': 'Bookstores', 'parents': ['media']},
#  {'alias': 'bootcamps',
#   'title': 'Boot Camps',
#   'parents': ['fitness'],
#   'country_whitelist': ['AU',
#    'IT',
#    'PL',
#    'PT',
#    'NZ',
#    'NO',
#    'ES',
#    'SE',
#    'DK',
#    'CZ',
#    'US']},
#  {'alias': 'boudoirphotography',
#   'title': 'Boudoir Photography',
#   'parents': ['photographers'],
#   'country_whitelist': ['SE', 'US', 'CA', 'DE']},
#  {'alias': 'bouncehouserentals',
#   'title': 'Bounce House Rentals',
#   'parents': ['partyequipmentrentals'],
#   'country_whitelist': ['SE', 'DE', 'CH', 'AT', 'US', 'CA']},
#  {'alias': 'bourguignon',
#   'title': 'Bourguignon',
#   'parents': ['french'],
#   'country_whitelist': ['FR']},
#  {'alias': 'bowling', 'title': 'Bowling', 'parents': ['active']},
#  {'alias': 'boxing',
#   'title': 'Boxing',
#   'parents': ['fitness'],
#   'country_blacklist': ['SE', 'AU', 'PL', 'FI', 'SG', 'TR', 'ES']},
#  {'alias': 'brasseries',
#   'title': 'Brasseries',
#   'parents': ['restaurants'],
#   'country_blacklist': ['MX', 'AR']},
#  {'alias': 'brazilian', 'title': 'Brazilian', 'parents': ['restaurants']},
#  {'alias': 'brazilianempanadas',
#   'title': 'Brazilian Empanadas',
#   'parents': ['brazilian'],
#   'country_whitelist': ['BR']},
#  {'alias': 'brazilianjiujitsu',
#   'title': 'Brazilian Jiu-jitsu',
#   'parents': ['martialarts']},
#  {'alias': 'breakfast_brunch',
#   'title': 'Breakfast & Brunch',
#   'parents': ['restaurants']},
#  {'alias': 'breweries', 'title': 'Breweries', 'parents': ['food']},
#  {'alias': 'brewingsupplies',
#   'title': 'Brewing Supplies',
#   'parents': ['shopping'],
#   'country_blacklist': ['JP', 'CL', 'HK', 'AR']},
#  {'alias': 'brewpubs',
#   'title': 'Brewpubs',
#   'parents': ['breweries'],
#   'country_blacklist': ['MX', 'FR', 'CL', 'IT', 'ES', 'AR']},
#  {'alias': 'bridal', 'title': 'Bridal', 'parents': ['shopping']},
#  {'alias': 'british',
#   'title': 'British',
#   'parents': ['restaurants'],
#   'country_blacklist': ['FI']},
#  {'alias': 'bubblesoccer', 'title': 'Bubble Soccer', 'parents': ['active']},
#  {'alias': 'bubbletea',
#   'title': 'Bubble Tea',
#   'parents': ['food'],
#   'country_blacklist': ['MX', 'TR', 'CH', 'AT', 'ES', 'AR']},
#  {'alias': 'buddhist_temples',
#   'title': 'Buddhist Temples',
#   'parents': ['religiousorgs']},
#  {'alias': 'buffets', 'title': 'Buffets', 'parents': ['restaurants']},
#  {'alias': 'buildingsupplies',
#   'title': 'Building Supplies',
#   'parents': ['homeservices']},
#  {'alias': 'bulgarian',
#   'title': 'Bulgarian',
#   'parents': ['restaurants'],
#   'country_blacklist': ['BR', 'SG', 'NL', 'NZ', 'NO', 'CA', 'DK', 'TR']},
#  {'alias': 'bulkbilling',
#   'title': 'Bulk Billing',
#   'parents': ['medcenters'],
#   'country_whitelist': ['AU']},
#  {'alias': 'bungeejumping', 'title': 'Bungee Jumping', 'parents': ['active']},
#  {'alias': 'burgers', 'title': 'Burgers', 'parents': ['restaurants']},
#  {'alias': 'burmese',
#   'title': 'Burmese',
#   'parents': ['restaurants'],
#   'country_blacklist': ['DK', 'PT', 'FI', 'TR', 'CZ', 'ES']},
#  {'alias': 'buses', 'title': 'Buses', 'parents': ['transport']},
#  {'alias': 'businessconsulting',
#   'title': 'Business Consulting',
#   'parents': ['professional'],
#   'country_blacklist': ['HK', 'FI', 'TR', 'CZ', 'TW']},
#  {'alias': 'businessfinancing',
#   'title': 'Business Financing',
#   'parents': ['financialservices']},
#  {'alias': 'businesslawyers',
#   'title': 'Business Law',
#   'parents': ['lawyers'],
#   'country_whitelist': ['PL',
#    'PT',
#    'BR',
#    'NO',
#    'CA',
#    'IE',
#    'DK',
#    'CZ',
#    'GB',
#    'US']},
#  {'alias': 'busrental', 'title': 'Bus Rental', 'parents': ['localservices']},
#  {'alias': 'busstations',
#   'title': 'Bus Stations',
#   'parents': ['transport'],
#   'country_blacklist': ['FR']},
#  {'alias': 'bustours', 'title': 'Bus Tours', 'parents': ['tours']},
#  {'alias': 'butcher',
#   'title': 'Butcher',
#   'parents': ['food'],
#   'country_blacklist': ['CH', 'AT', 'DE']},
#  {'alias': 'c_and_mh',
#   'title': 'Counseling & Mental Health',
#   'parents': ['health']},
#  {'alias': 'cabaret',
#   'title': 'Cabaret',
#   'parents': ['arts'],
#   'country_blacklist': ['HK', 'MX', 'JP', 'CL', 'AR']},
#  {'alias': 'cabinetry',
#   'title': 'Cabinetry',
#   'parents': ['homeservices'],
#   'country_blacklist': ['HK', 'MX', 'JP', 'CL', 'AR']},
#  {'alias': 'cablecars',
#   'title': 'Cable Cars',
#   'parents': ['transport'],
#   'country_whitelist': ['DE',
#    'US',
#    'PT',
#    'BR',
#    'NZ',
#    'AT',
#    'FR',
#    'JP',
#    'TR',
#    'CH',
#    'CZ',
#    'IT']},
#  {'alias': 'cafes',
#   'title': 'Cafes',
#   'parents': ['restaurants'],
#   'country_blacklist': ['MX', 'FI', 'ES', 'AR']},
#  {'alias': 'cafeteria',
#   'title': 'Cafeteria',
#   'parents': ['restaurants'],
#   'country_blacklist': ['SE', 'IE', 'BR', 'FR', 'SG', 'NZ', 'CA']},
#  {'alias': 'cajun',
#   'title': 'Cajun/Creole',
#   'parents': ['restaurants'],
#   'country_blacklist': ['PT', 'AU', 'ES', 'SG']},
#  {'alias': 'cakeshop', 'title': 'Patisserie/Cake Shop', 'parents': ['food']},
#  {'alias': 'calabrian',
#   'title': 'Calabrian',
#   'parents': ['italian'],
#   'country_whitelist': ['US', 'IT', 'FR']},
#  {'alias': 'calligraphy',
#   'title': 'Calligraphy',
#   'parents': ['localservices'],
#   'country_whitelist': ['US', 'BR', 'TR', 'NL', 'BE', 'IT', 'ES']},
#  {'alias': 'cambodian',
#   'title': 'Cambodian',
#   'parents': ['restaurants'],
#   'country_blacklist': ['DK', 'PT', 'FI', 'TR', 'CZ', 'ES']},
#  {'alias': 'campgrounds', 'title': 'Campgrounds', 'parents': ['hotelstravel']},
#  {'alias': 'candlestores',
#   'title': 'Candle Stores',
#   'parents': ['homeandgarden']},
#  {'alias': 'candy', 'title': 'Candy Stores', 'parents': ['gourmet']},
#  {'alias': 'cannabis_clinics',
#   'title': 'Cannabis Clinics',
#   'parents': ['health'],
#   'country_whitelist': ['PL', 'US', 'NL', 'CA', 'IE', 'TR', 'GB', 'IT']},
#  {'alias': 'cannabiscollective',
#   'title': 'Cannabis Collective',
#   'parents': ['health'],
#   'country_whitelist': ['US', 'CA']},
#  {'alias': 'cannabisdispensaries',
#   'title': 'Cannabis Dispensaries',
#   'parents': ['shopping'],
#   'country_whitelist': ['US']},
#  {'alias': 'cannabisreferrals',
#   'title': 'Medical Cannabis Referrals',
#   'parents': ['health'],
#   'country_whitelist': ['US']},
#  {'alias': 'cannabistours',
#   'title': 'Cannabis Tours',
#   'parents': ['cannabis_clinics'],
#   'country_whitelist': ['US']},
#  {'alias': 'canteen',
#   'title': 'Canteen',
#   'parents': ['restaurants'],
#   'country_whitelist': ['DE',
#    'PL',
#    'NL',
#    'BE',
#    'AT',
#    'NO',
#    'DK',
#    'JP',
#    'FI',
#    'CH',
#    'CZ',
#    'IT']},
#  {'alias': 'cantonese',
#   'title': 'Cantonese',
#   'parents': ['chinese'],
#   'country_whitelist': ['SG',
#    'NL',
#    'NZ',
#    'FR',
#    'CA',
#    'SE',
#    'IT',
#    'AR',
#    'MY',
#    'HK',
#    'AU',
#    'BE',
#    'JP',
#    'GB',
#    'US',
#    'TW']},
#  {'alias': 'car_dealers', 'title': 'Car Dealers', 'parents': ['auto']},
#  {'alias': 'carauctions',
#   'title': 'Car Auctions',
#   'parents': ['auto'],
#   'country_whitelist': ['MY', 'HK', 'SG', 'PH', 'US', 'TW']},
#  {'alias': 'carbrokers',
#   'title': 'Car Brokers',
#   'parents': ['auto'],
#   'country_whitelist': ['US', 'AU', 'AR', 'NZ']},
#  {'alias': 'carbuyers',
#   'title': 'Car Buyers',
#   'parents': ['auto'],
#   'country_whitelist': ['AU',
#    'DE',
#    'US',
#    'BR',
#    'SG',
#    'NL',
#    'NZ',
#    'AT',
#    'BE',
#    'CA',
#    'IE',
#    'CH',
#    'GB',
#    'CZ']},
#  {'alias': 'cardioclasses', 'title': 'Cardio Classes', 'parents': ['fitness']},
#  {'alias': 'cardiology', 'title': 'Cardiologists', 'parents': ['physicians']},
#  {'alias': 'careercounseling',
#   'title': 'Career Counseling',
#   'parents': ['professional']},
#  {'alias': 'caribbean',
#   'title': 'Caribbean',
#   'parents': ['restaurants'],
#   'country_blacklist': ['PT', 'FI', 'TR']},
#  {'alias': 'caricatures',
#   'title': 'Caricatures',
#   'parents': ['eventservices'],
#   'country_whitelist': ['IT', 'PL', 'BR', 'SG', 'ES', 'NO', 'SE', 'DK', 'US']},
#  {'alias': 'carousels', 'title': 'Carousels', 'parents': ['active']},
#  {'alias': 'carpenters',
#   'title': 'Carpenters',
#   'parents': ['homeservices'],
#   'country_blacklist': ['TR']},
#  {'alias': 'carpet_cleaning',
#   'title': 'Carpet Cleaning',
#   'parents': ['localservices']},
#  {'alias': 'carpetdyeing',
#   'title': 'Carpet Dyeing',
#   'parents': ['localservices'],
#   'country_whitelist': ['US']},
#  {'alias': 'carpeting', 'title': 'Carpeting', 'parents': ['homeservices']},
#  {'alias': 'carpetinstallation',
#   'title': 'Carpet Installation',
#   'parents': ['homeservices']},
#  {'alias': 'carrental', 'title': 'Car Rental', 'parents': ['hotelstravel']},
#  {'alias': 'carshares',
#   'title': 'Car Share Services',
#   'parents': ['auto'],
#   'country_blacklist': ['HK',
#    'PT',
#    'BR',
#    'SG',
#    'NL',
#    'BE',
#    'JP',
#    'FI',
#    'TR',
#    'TW']},
#  {'alias': 'carwash', 'title': 'Car Wash', 'parents': ['auto']},
#  {'alias': 'carwindowtinting',
#   'title': 'Car Window Tinting',
#   'parents': ['autoglass'],
#   'country_whitelist': ['AU',
#    'IT',
#    'SG',
#    'NL',
#    'NZ',
#    'BE',
#    'ES',
#    'CA',
#    'IE',
#    'GB',
#    'US']},
#  {'alias': 'casinos',
#   'title': 'Casinos',
#   'parents': ['arts'],
#   'country_blacklist': ['JP', 'HK']},
#  {'alias': 'castles',
#   'title': 'Castles',
#   'parents': ['arts'],
#   'country_whitelist': ['DE',
#    'PT',
#    'BE',
#    'AT',
#    'FR',
#    'ES',
#    'NO',
#    'SE',
#    'DK',
#    'JP',
#    'FI',
#    'CH',
#    'CZ',
#    'GB',
#    'IT']},
#  {'alias': 'catalan',
#   'title': 'Catalan',
#   'parents': ['restaurants'],
#   'country_whitelist': ['IT', 'MX', 'PT', 'FR', 'ES', 'TR', 'CL', 'US', 'AR']},
#  {'alias': 'catering', 'title': 'Caterers', 'parents': ['eventservices']},
#  {'alias': 'cellphoneaccessories',
#   'title': 'Mobile Phone Accessories',
#   'parents': ['shopping'],
#   'country_blacklist': ['MY', 'PL', 'FI', 'TR', 'PH']},
#  {'alias': 'centralbrazilian',
#   'title': 'Central Brazilian',
#   'parents': ['brazilian'],
#   'country_whitelist': ['BR']},
#  {'alias': 'ceremonialclothing',
#   'title': 'Ceremonial Clothing',
#   'parents': ['fashion'],
#   'country_blacklist': ['DE', 'JP', 'CH', 'AT', 'FR']},
#  {'alias': 'challengecourses',
#   'title': 'Challenge Courses',
#   'parents': ['active'],
#   'country_whitelist': ['HK',
#    'DE',
#    'PL',
#    'SG',
#    'NZ',
#    'AT',
#    'FR',
#    'CA',
#    'NO',
#    'SE',
#    'DK',
#    'CH',
#    'CZ',
#    'US']},
#  {'alias': 'champagne_bars',
#   'title': 'Champagne Bars',
#   'parents': ['bars'],
#   'country_blacklist': ['AU']},
#  {'alias': 'cheekufta',
#   'title': 'Chee Kufta',
#   'parents': ['turkish'],
#   'country_whitelist': ['TR', 'DE']},
#  {'alias': 'cheerleading',
#   'title': 'Cheerleading',
#   'parents': ['specialtyschools'],
#   'country_whitelist': ['SE', 'DE', 'CH', 'AT', 'US', 'CA']},
#  {'alias': 'cheese', 'title': 'Cheese Shops', 'parents': ['gourmet']},
#  {'alias': 'cheesesteaks',
#   'title': 'Cheesesteaks',
#   'parents': ['restaurants'],
#   'country_whitelist': ['IE', 'AU', 'PL', 'NL', 'GB', 'US', 'CA']},
#  {'alias': 'cheesetastingclasses',
#   'title': 'Cheese Tasting Classes',
#   'parents': ['tastingclasses']},
#  {'alias': 'chicken_wings',
#   'title': 'Chicken Wings',
#   'parents': ['restaurants'],
#   'country_blacklist': ['PT',
#    'NL',
#    'BE',
#    'FR',
#    'ES',
#    'NO',
#    'DK',
#    'JP',
#    'FI',
#    'CH',
#    'CL',
#    'IT']},
#  {'alias': 'chickenshop',
#   'title': 'Chicken Shop',
#   'parents': ['restaurants'],
#   'country_blacklist': ['CZ']},
#  {'alias': 'childbirthedu',
#   'title': 'Childbirth Education',
#   'parents': ['specialtyschools'],
#   'country_whitelist': ['AU',
#    'IT',
#    'BR',
#    'ES',
#    'NO',
#    'FR',
#    'SE',
#    'IE',
#    'DK',
#    'GB',
#    'US']},
#  {'alias': 'childcare',
#   'title': 'Child Care & Day Care',
#   'parents': ['localservices']},
#  {'alias': 'childcloth',
#   'title': "Children's Clothing",
#   'parents': ['fashion']},
#  {'alias': 'childproofing',
#   'title': 'Childproofing',
#   'parents': ['homeservices'],
#   'country_whitelist': ['PT', 'US', 'BR']},
#  {'alias': 'childrensmuseums',
#   'title': "Children's Museums",
#   'parents': ['museums'],
#   'country_blacklist': ['FR']},
#  {'alias': 'chilean',
#   'title': 'Chilean',
#   'parents': ['restaurants'],
#   'country_whitelist': ['CL', 'BR', 'FR', 'FI']},
#  {'alias': 'chimneycakes',
#   'title': 'Chimney Cakes',
#   'parents': ['food'],
#   'country_whitelist': ['PL', 'US', 'CZ', 'FR']},
#  {'alias': 'chimneysweeps',
#   'title': 'Chimney Sweeps',
#   'parents': ['homeservices'],
#   'country_blacklist': ['MX']},
#  {'alias': 'chinese', 'title': 'Chinese', 'parents': ['restaurants']},
#  {'alias': 'chinesebazaar',
#   'title': 'Chinese Bazaar',
#   'parents': ['shopping'],
#   'country_whitelist': ['PT', 'ES']},
#  {'alias': 'chinesemartialarts',
#   'title': 'Chinese Martial Arts',
#   'parents': ['martialarts']},
#  {'alias': 'chiropractors', 'title': 'Chiropractors', 'parents': ['health']},
#  {'alias': 'chocolate',
#   'title': 'Chocolatiers & Shops',
#   'parents': ['gourmet']},
#  {'alias': 'choirs',
#   'title': 'Choirs',
#   'parents': ['arts'],
#   'country_blacklist': ['PL', 'BR', 'SG', 'NL', 'NZ', 'BE', 'CA', 'CZ', 'US']},
#  {'alias': 'christmastrees',
#   'title': 'Christmas Trees',
#   'parents': ['homeandgarden']},
#  {'alias': 'churches', 'title': 'Churches', 'parents': ['religiousorgs']},
#  {'alias': 'churros',
#   'title': 'Churros',
#   'parents': ['food'],
#   'country_whitelist': ['MX', 'PT', 'BR', 'CL', 'ES', 'AR']},
#  {'alias': 'cideries',
#   'title': 'Cideries',
#   'parents': ['food'],
#   'country_blacklist': ['NL', 'BE', 'FR', 'NO', 'DK', 'JP', 'TR', 'IT']},
#  {'alias': 'cigarbars',
#   'title': 'Cigar Bars',
#   'parents': ['bars'],
#   'country_whitelist': ['US']},
#  {'alias': 'circuittraininggyms',
#   'title': 'Circuit Training Gyms',
#   'parents': ['gyms'],
#   'country_whitelist': ['US']},
#  {'alias': 'circusschools',
#   'title': 'Circus Schools',
#   'parents': ['specialtyschools'],
#   'country_whitelist': ['MX', 'PT', 'BR', 'FR', 'ES', 'FI', 'CL', 'AR']},
#  {'alias': 'civiccenter',
#   'title': 'Civic Center',
#   'parents': ['publicservicesgovt'],
#   'country_whitelist': ['US']},
#  {'alias': 'climbing', 'title': 'Climbing', 'parents': ['active']},
#  {'alias': 'clockrepair',
#   'title': 'Clock Repair',
#   'parents': ['localservices'],
#   'country_blacklist': ['MX', 'JP', 'CL', 'IT', 'AR']},
#  {'alias': 'clothingrental',
#   'title': 'Clothing Rental',
#   'parents': ['fashion']},
#  {'alias': 'clowns',
#   'title': 'Clowns',
#   'parents': ['eventservices'],
#   'country_blacklist': ['SE', 'PL', 'FI', 'SG', 'TR', 'CZ']},
#  {'alias': 'clubcrawl',
#   'title': 'Club Crawl',
#   'parents': ['nightlife'],
#   'country_whitelist': ['US']},
#  {'alias': 'cocktailbars', 'title': 'Cocktail Bars', 'parents': ['bars']},
#  {'alias': 'coffee', 'title': 'Coffee & Tea', 'parents': ['food']},
#  {'alias': 'coffeeroasteries',
#   'title': 'Coffee Roasteries',
#   'parents': ['food']},
#  {'alias': 'coffeeshops',
#   'title': 'Coffeeshops',
#   'parents': ['nightlife'],
#   'country_whitelist': ['PT', 'NL']},
#  {'alias': 'coffeeteasupplies',
#   'title': 'Coffee & Tea Supplies',
#   'parents': ['food'],
#   'country_blacklist': ['MY',
#    'US',
#    'MX',
#    'PT',
#    'BR',
#    'PH',
#    'ES',
#    'FI',
#    'CL',
#    'CZ',
#    'IT',
#    'AR']},
#  {'alias': 'collegecounseling',
#   'title': 'College Counseling',
#   'parents': ['education'],
#   'country_whitelist': ['PT', 'US']},
#  {'alias': 'collegeuniv',
#   'title': 'Colleges & Universities',
#   'parents': ['education']},
#  {'alias': 'colombian',
#   'title': 'Colombian',
#   'parents': ['latin'],
#   'country_whitelist': ['MX', 'BE', 'FR', 'ES', 'CA', 'FI', 'CL', 'US', 'AR']},
#  {'alias': 'colonics',
#   'title': 'Colonics',
#   'parents': ['health'],
#   'country_whitelist': ['AU', 'SG', 'NZ', 'NO', 'CA', 'IE', 'DK', 'GB', 'US']},
#  {'alias': 'comedyclubs',
#   'title': 'Comedy Clubs',
#   'parents': ['nightlife'],
#   'country_blacklist': ['CZ']},
#  {'alias': 'comfortfood',
#   'title': 'Comfort Food',
#   'parents': ['restaurants'],
#   'country_whitelist': ['MX', 'JP', 'FI', 'CL', 'US', 'CA', 'AR']},
#  {'alias': 'comicbooks', 'title': 'Comic Books', 'parents': ['media']},
#  {'alias': 'commercialrealestate',
#   'title': 'Commercial Real Estate',
#   'parents': ['realestate'],
#   'country_whitelist': ['AU',
#    'DE',
#    'PL',
#    'PT',
#    'BR',
#    'NL',
#    'BE',
#    'CA',
#    'NO',
#    'DK',
#    'CZ',
#    'US']},
#  {'alias': 'commissionedartists',
#   'title': 'Commissioned Artists',
#   'parents': ['professional'],
#   'country_blacklist': ['FR']},
#  {'alias': 'communitybookbox',
#   'title': 'Community Book Box',
#   'parents': ['localservices'],
#   'country_blacklist': ['MY', 'MX', 'PH', 'FR', 'ES', 'JP', 'CL', 'IT', 'AR']},
#  {'alias': 'communitycenters',
#   'title': 'Community Centers',
#   'parents': ['publicservicesgovt'],
#   'country_whitelist': ['PT',
#    'BR',
#    'NO',
#    'CA',
#    'SE',
#    'IE',
#    'DK',
#    'CZ',
#    'GB',
#    'US']},
#  {'alias': 'communitygardens',
#   'title': 'Community Gardens',
#   'parents': ['localservices'],
#   'country_whitelist': ['AU',
#    'DE',
#    'PT',
#    'BR',
#    'SG',
#    'FR',
#    'NO',
#    'ES',
#    'SE',
#    'DK',
#    'US']},
#  {'alias': 'computers', 'title': 'Computers', 'parents': ['shopping']},
#  {'alias': 'concept_shops',
#   'title': 'Concept Shops',
#   'parents': ['shopping'],
#   'country_blacklist': ['HK',
#    'IT',
#    'PL',
#    'BR',
#    'SG',
#    'NZ',
#    'ES',
#    'CA',
#    'SE',
#    'JP',
#    'TR',
#    'CL',
#    'US',
#    'AR']},
#  {'alias': 'conciergemedicine',
#   'title': 'Concierge Medicine',
#   'parents': ['health'],
#   'country_whitelist': ['US']},
#  {'alias': 'condominiums',
#   'title': 'Condominiums',
#   'parents': ['realestate'],
#   'country_blacklist': ['AU', 'NZ']},
#  {'alias': 'congee',
#   'title': 'Congee',
#   'parents': ['chinese'],
#   'country_whitelist': ['TW', 'MY', 'HK', 'SG']},
#  {'alias': 'contractlaw',
#   'title': 'Contract Law',
#   'parents': ['lawyers'],
#   'country_blacklist': ['FR']},
#  {'alias': 'contractors', 'title': 'Contractors', 'parents': ['homeservices']},
#  {'alias': 'convenience',
#   'title': 'Convenience Stores',
#   'parents': ['food'],
#   'country_blacklist': ['FI']},
#  {'alias': 'conveyorsushi',
#   'title': 'Conveyor Belt Sushi',
#   'parents': ['japanese'],
#   'country_whitelist': ['HK',
#    'DE',
#    'IT',
#    'PL',
#    'SG',
#    'NL',
#    'BE',
#    'AT',
#    'SE',
#    'JP',
#    'CH',
#    'US',
#    'TW']},
#  {'alias': 'cookingclasses',
#   'title': 'Cooking Classes',
#   'parents': ['artsandcrafts']},
#  {'alias': 'cookingschools',
#   'title': 'Cooking Schools',
#   'parents': ['specialtyschools']},
#  {'alias': 'copyshops',
#   'title': 'Printing Services',
#   'parents': ['localservices']},
#  {'alias': 'corsican',
#   'title': 'Corsican',
#   'parents': ['restaurants'],
#   'country_whitelist': ['BE', 'FR']},
#  {'alias': 'cosmeticdentists',
#   'title': 'Cosmetic Dentists',
#   'parents': ['dentists'],
#   'country_blacklist': ['CZ']},
#  {'alias': 'cosmetics',
#   'title': 'Cosmetics & Beauty Supply',
#   'parents': ['shopping', 'beautysvc']},
#  {'alias': 'cosmeticsurgeons',
#   'title': 'Cosmetic Surgeons',
#   'parents': ['physicians']},
#  {'alias': 'cosmetology_schools',
#   'title': 'Cosmetology Schools',
#   'parents': ['specialtyschools']},
#  {'alias': 'costumes', 'title': 'Costumes', 'parents': ['artsandcrafts']},
#  {'alias': 'countertopinstall',
#   'title': 'Countertop Installation',
#   'parents': ['homeservices'],
#   'country_blacklist': ['DE', 'IT', 'CH', 'AT', 'CZ', 'FR']},
#  {'alias': 'countryclubs',
#   'title': 'Country Clubs',
#   'parents': ['arts'],
#   'country_whitelist': ['HK',
#    'IT',
#    'MX',
#    'BR',
#    'SG',
#    'ES',
#    'JP',
#    'CL',
#    'US',
#    'TW',
#    'AR']},
#  {'alias': 'countrydancehalls',
#   'title': 'Country Dance Halls',
#   'parents': ['nightlife'],
#   'country_whitelist': ['SE', 'US']},
#  {'alias': 'couriers',
#   'title': 'Couriers & Delivery Services',
#   'parents': ['localservices']},
#  {'alias': 'courthouses',
#   'title': 'Courthouses',
#   'parents': ['publicservicesgovt'],
#   'country_blacklist': ['SG',
#    'NZ',
#    'PH',
#    'ES',
#    'CA',
#    'IE',
#    'TR',
#    'AR',
#    'MY',
#    'HK',
#    'MX',
#    'JP',
#    'FI',
#    'CL',
#    'GB',
#    'TW']},
#  {'alias': 'courtreporters',
#   'title': 'Court Reporters',
#   'parents': ['legalservices'],
#   'country_whitelist': ['BE', 'NL', 'US', 'CA']},
#  {'alias': 'cprclasses',
#   'title': 'CPR Classes',
#   'parents': ['specialtyschools'],
#   'country_whitelist': ['US', 'SE', 'PT', 'AU']},
#  {'alias': 'craneservices',
#   'title': 'Crane Services',
#   'parents': ['localservices'],
#   'country_blacklist': ['MY', 'HK', 'PH', 'FR', 'JP', 'FI', 'TR', 'TW']},
#  {'alias': 'cremationservices',
#   'title': 'Cremation Services',
#   'parents': ['funeralservices'],
#   'country_blacklist': ['TR']},
#  {'alias': 'creperies', 'title': 'Creperies', 'parents': ['restaurants']},
#  {'alias': 'criminaldefense',
#   'title': 'Criminal Defense Law',
#   'parents': ['lawyers']},
#  {'alias': 'cryotherapy',
#   'title': 'Cryotherapy',
#   'parents': ['health'],
#   'country_whitelist': ['US', 'IT']},
#  {'alias': 'csa',
#   'title': 'CSA',
#   'parents': ['food'],
#   'country_whitelist': ['DE', 'CH', 'AT', 'US', 'FR']},
#  {'alias': 'cuban',
#   'title': 'Cuban',
#   'parents': ['restaurants'],
#   'country_blacklist': ['SG', 'DK', 'TR']},
#  {'alias': 'cucinacampana',
#   'title': 'Cucina campana',
#   'parents': ['italian'],
#   'country_whitelist': ['IT']},
#  {'alias': 'culturalcenter',
#   'title': 'Cultural Center',
#   'parents': ['arts'],
#   'country_blacklist': ['TR', 'IE', 'CA', 'NZ']},
#  {'alias': 'cupcakes',
#   'title': 'Cupcakes',
#   'parents': ['food'],
#   'country_blacklist': ['CZ', 'CA', 'ES', 'TR']},
#  {'alias': 'currencyexchange',
#   'title': 'Currency Exchange',
#   'parents': ['financialservices']},
#  {'alias': 'currysausage',
#   'title': 'Curry Sausage',
#   'parents': ['restaurants'],
#   'country_whitelist': ['CH', 'AT', 'DE']},
#  {'alias': 'customcakes',
#   'title': 'Custom Cakes',
#   'parents': ['food'],
#   'country_blacklist': ['CH', 'AT', 'FR', 'DE']},
#  {'alias': 'custommerchandise',
#   'title': 'Customized Merchandise',
#   'parents': ['shopping']},
#  {'alias': 'customsbrokers',
#   'title': 'Customs Brokers',
#   'parents': ['professional']},
#  {'alias': 'cyclingclasses',
#   'title': 'Cycling Classes',
#   'parents': ['active'],
#   'country_blacklist': ['IE', 'MX', 'PT', 'BR', 'NZ', 'CA', 'AR']},
#  {'alias': 'cypriot',
#   'title': 'Cypriot',
#   'parents': ['restaurants'],
#   'country_whitelist': ['CH', 'AT', 'DE']},
#  {'alias': 'czech',
#   'title': 'Czech',
#   'parents': ['restaurants'],
#   'country_whitelist': ['AU',
#    'DE',
#    'PL',
#    'US',
#    'BE',
#    'FR',
#    'CA',
#    'NO',
#    'SE',
#    'IE',
#    'DK',
#    'FI',
#    'CZ',
#    'GB',
#    'IT']},
#  {'alias': 'czechslovakian',
#   'title': 'Czech/Slovakian',
#   'parents': ['restaurants'],
#   'country_whitelist': ['MX', 'PT', 'AR']},
#  {'alias': 'dagashi',
#   'title': 'Dagashi',
#   'parents': ['gourmet'],
#   'country_whitelist': ['JP']},
#  {'alias': 'damagerestoration',
#   'title': 'Damage Restoration',
#   'parents': ['homeservices'],
#   'country_whitelist': ['AU', 'PT', 'SG', 'TR', 'NZ', 'US', 'CA']},
#  {'alias': 'dance_schools',
#   'title': 'Dance Schools',
#   'parents': ['specialtyschools']},
#  {'alias': 'danceclubs', 'title': 'Dance Clubs', 'parents': ['nightlife']},
#  {'alias': 'dancerestaurants',
#   'title': 'Dance Restaurants',
#   'parents': ['nightlife'],
#   'country_whitelist': ['FI']},
#  {'alias': 'dancestudio', 'title': 'Dance Studios', 'parents': ['fitness']},
#  {'alias': 'dancewear', 'title': 'Dance Wear', 'parents': ['sportswear']},
#  {'alias': 'danish',
#   'title': 'Danish',
#   'parents': ['restaurants'],
#   'country_whitelist': ['SE', 'NO', 'FR', 'DK']},
#  {'alias': 'datarecovery',
#   'title': 'Data Recovery',
#   'parents': ['itservices'],
#   'country_blacklist': ['MY', 'HK', 'JP', 'FI', 'NL', 'PH', 'TW']},
#  {'alias': 'daycamps',
#   'title': 'Day Camps',
#   'parents': ['active'],
#   'country_blacklist': ['HK', 'MX', 'JP', 'CL', 'AR']},
#  {'alias': 'debtrelief',
#   'title': 'Debt Relief Services',
#   'parents': ['financialservices'],
#   'country_whitelist': ['US', 'CA']},
#  {'alias': 'decksrailing',
#   'title': 'Decks & Railing',
#   'parents': ['homeservices']},
#  {'alias': 'delicatessen',
#   'title': 'Delicatessen',
#   'parents': ['food'],
#   'country_blacklist': ['US']},
#  {'alias': 'delis',
#   'title': 'Delis',
#   'parents': ['restaurants'],
#   'country_blacklist': ['SE', 'PT', 'NL', 'CL', 'BE', 'IT', 'FR']},
#  {'alias': 'demolitionservices',
#   'title': 'Demolition Services',
#   'parents': ['homeservices'],
#   'country_whitelist': ['AU',
#    'DE',
#    'PL',
#    'US',
#    'PT',
#    'BR',
#    'NL',
#    'BE',
#    'AT',
#    'ES',
#    'NO',
#    'DK',
#    'CH',
#    'CZ',
#    'IT']},
#  {'alias': 'dentalhygeiniststorefront',
#   'title': 'Storefront Clinics',
#   'parents': ['dentalhygienists'],
#   'country_whitelist': ['CA']},
#  {'alias': 'dentalhygienists',
#   'title': 'Dental Hygienists',
#   'parents': ['health'],
#   'country_whitelist': ['DK', 'DE', 'PT', 'NL', 'CA', 'US', 'NO']},
#  {'alias': 'dentalhygienistsmobile',
#   'title': 'Mobile Clinics',
#   'parents': ['dentalhygienists'],
#   'country_whitelist': ['CA']},
#  {'alias': 'dentists', 'title': 'Dentists', 'parents': ['health']},
#  {'alias': 'departmentsofmotorvehicles',
#   'title': 'Departments of Motor Vehicles',
#   'parents': ['publicservicesgovt'],
#   'country_blacklist': ['BE', 'FR']},
#  {'alias': 'deptstores',
#   'title': 'Department Stores',
#   'parents': ['shopping', 'fashion']},
#  {'alias': 'dermatology',
#   'title': 'Dermatologists',
#   'parents': ['physicians']},
#  {'alias': 'desserts', 'title': 'Desserts', 'parents': ['food']},
#  {'alias': 'diagnosticimaging',
#   'title': 'Diagnostic Imaging',
#   'parents': ['diagnosticservices'],
#   'country_whitelist': ['AU',
#    'MX',
#    'PT',
#    'BR',
#    'FR',
#    'ES',
#    'CA',
#    'IE',
#    'CL',
#    'GB',
#    'US',
#    'AR']},
#  {'alias': 'diagnosticservices',
#   'title': 'Diagnostic Services',
#   'parents': ['health']},
#  {'alias': 'dialysisclinics',
#   'title': 'Dialysis Clinics',
#   'parents': ['health'],
#   'country_whitelist': ['IT', 'MX', 'PT', 'BR', 'ES', 'TR', 'CL', 'US', 'AR']},
#  {'alias': 'dietitians', 'title': 'Dietitians', 'parents': ['health']},
#  {'alias': 'digitizingservices',
#   'title': 'Digitizing Services',
#   'parents': ['professional'],
#   'country_whitelist': ['NO', 'US', 'BR', 'DK']},
#  {'alias': 'dimsum',
#   'title': 'Dim Sum',
#   'parents': ['chinese'],
#   'country_blacklist': ['PT', 'BR', 'TR']},
#  {'alias': 'diners',
#   'title': 'Diners',
#   'parents': ['restaurants'],
#   'country_blacklist': ['SE', 'FI', 'AU', 'CZ']},
#  {'alias': 'dinnertheater',
#   'title': 'Dinner Theater',
#   'parents': ['restaurants'],
#   'country_blacklist': ['JP', 'NL', 'BE', 'IT', 'FR']},
#  {'alias': 'disabilitylaw', 'title': 'Disability Law', 'parents': ['lawyers']},
#  {'alias': 'discgolf',
#   'title': 'Disc Golf',
#   'parents': ['active'],
#   'country_blacklist': ['AU', 'SG', 'DK']},
#  {'alias': 'discountstore',
#   'title': 'Discount Store',
#   'parents': ['shopping']},
#  {'alias': 'distilleries', 'title': 'Distilleries', 'parents': ['food']},
#  {'alias': 'divebars',
#   'title': 'Dive Bars',
#   'parents': ['bars'],
#   'country_blacklist': ['AU', 'NL', 'CZ', 'BE', 'IT', 'FR']},
#  {'alias': 'diveshops',
#   'title': 'Dive Shops',
#   'parents': ['sportgoods'],
#   'country_whitelist': ['AU',
#    'DE',
#    'IT',
#    'MX',
#    'BR',
#    'NZ',
#    'AT',
#    'ES',
#    'JP',
#    'CH',
#    'CL',
#    'US',
#    'AR']},
# ...
#  {'alias': 'menscloth', 'title': "Men's Clothing", 'parents': ['fashion']},
#  {'alias': 'menshair',
#   'title': "Men's Hair Salons",
#   'parents': ['hair'],
#   'country_whitelist': ['AU',
#    'MX',
#    'PT',
#    'NL',
#    'BE',
#    'ES',
#    'NO',
#    'DK',
#    'CL',
#    'CZ',
#    'US',
#    'AR']},
#  {'alias': 'metaldetectorservices',
#   'title': 'Metal Detector Services',
#   'parents': ['localservices']},
#  {'alias': 'metalfabricators',
#   'title': 'Metal Fabricators',
#   'parents': ['localservices'],
#   'country_blacklist': ['MX', 'SE', 'AR']},
#  {'alias': 'metrostations',
#   'title': 'Metro Stations',
#   'parents': ['transport']},
#  {'alias': 'mexican', 'title': 'Mexican', 'parents': ['restaurants']},
#  {'alias': 'mideastern',
#   'title': 'Middle Eastern',
#   'parents': ['restaurants'],
#   'country_blacklist': ['BR']},
#  {'alias': 'midwives', 'title': 'Midwives', 'parents': ['health']},
#  {'alias': 'militarysurplus',
#   'title': 'Military Surplus',
#   'parents': ['shopping']},
#  {'alias': 'milkbars',
#   'title': 'Milk Bars',
#   'parents': ['restaurants'],
#   'country_whitelist': ['PL', 'AU']},
#  {'alias': 'milkshakebars',
#   'title': 'Milkshake Bars',
#   'parents': ['food'],
#   'country_whitelist': ['GB']},
#  {'alias': 'minho',
#   'title': 'Minho',
#   'parents': ['portuguese'],
#   'country_whitelist': ['PT']},
#  {'alias': 'mini_golf',
#   'title': 'Mini Golf',
#   'parents': ['active'],
#   'country_blacklist': ['IT']},
#  {'alias': 'mistingsystemservices',
#   'title': 'Misting System Services',
#   'parents': ['localservices'],
#   'country_whitelist': ['US']},
#  {'alias': 'mobile_home_repair',
#   'title': 'Mobile Home Repair',
#   'parents': ['homeservices'],
#   'country_whitelist': ['SE', 'NL', 'BE', 'US', 'CA']},
#  {'alias': 'mobiledentrepair',
#   'title': 'Mobile Dent Repair',
#   'parents': ['auto'],
#   'country_whitelist': ['US', 'CA']},
#  {'alias': 'mobilehomes',
#   'title': 'Mobile Home Dealers',
#   'parents': ['realestate'],
#   'country_blacklist': ['CZ']},
#  {'alias': 'mobileparks',
#   'title': 'Mobile Home Parks',
#   'parents': ['realestate'],
#   'country_whitelist': ['US']},
#  {'alias': 'mobilephonerepair',
#   'title': 'Mobile Phone Repair',
#   'parents': ['itservices']},
#  {'alias': 'mobilephones', 'title': 'Mobile Phones', 'parents': ['shopping']},
#  {'alias': 'mobilityequipment',
#   'title': 'Mobility Equipment Sales & Services',
#   'parents': ['auto'],
#   'country_whitelist': ['US']},
#  {'alias': 'modern_australian',
#   'title': 'Modern Australian',
#   'parents': ['restaurants'],
#   'country_whitelist': ['AU']},
#  {'alias': 'modern_european',
#   'title': 'Modern European',
#   'parents': ['restaurants']},
#  {'alias': 'mohels',
#   'title': 'Mohels',
#   'parents': ['eventservices'],
#   'country_whitelist': ['US']},
#  {'alias': 'mongolian',
#   'title': 'Mongolian',
#   'parents': ['restaurants'],
#   'country_blacklist': ['PT', 'FI', 'ES', 'TR']},
#  {'alias': 'montessori',
#   'title': 'Montessori Schools',
#   'parents': ['education']},
#  {'alias': 'moroccan',
#   'title': 'Moroccan',
#   'parents': ['restaurants'],
#   'country_blacklist': ['TR']},
#  {'alias': 'mortgagebrokers',
#   'title': 'Mortgage Brokers',
#   'parents': ['realestate'],
#   'country_blacklist': ['BR', 'DK', 'ES']},
#  {'alias': 'mortgagelenders',
#   'title': 'Mortgage Lenders',
#   'parents': ['financialservices'],
#   'country_blacklist': ['DE', 'TR', 'CH', 'AT', 'FR']},
#  {'alias': 'mortuaryservices',
#   'title': 'Mortuary Services',
#   'parents': ['funeralservices'],
#   'country_blacklist': ['IT']},
#  {'alias': 'mosques', 'title': 'Mosques', 'parents': ['religiousorgs']},
#  {'alias': 'motodealers',
#   'title': 'Motorsport Vehicle Dealers',
#   'parents': ['auto'],
#   'country_whitelist': ['SE', 'IT', 'ES', 'US', 'TW']},
#  {'alias': 'motorcycle_rental',
#   'title': 'Motorcycle Rental',
#   'parents': ['hotelstravel'],
#   'country_whitelist': ['AU',
#    'DE',
#    'US',
#    'MX',
#    'PT',
#    'BR',
#    'SG',
#    'NZ',
#    'FR',
#    'NO',
#    'ES',
#    'FI',
#    'CZ',
#    'IT']},
#  {'alias': 'motorcycledealers',
#   'title': 'Motorcycle Dealers',
#   'parents': ['auto']},
#  {'alias': 'motorcyclerepair',
#   'title': 'Motorcycle Repair',
#   'parents': ['auto']},
#  {'alias': 'motorcyclinggear',
#   'title': 'Motorcycle Gear',
#   'parents': ['shopping'],
#   'country_blacklist': ['NZ', 'IE', 'CA', 'GB']},
#  {'alias': 'motorepairs',
#   'title': 'Motorsport Vehicle Repairs',
#   'parents': ['auto'],
#   'country_whitelist': ['SE', 'IT', 'ES', 'US', 'TW']},
#  {'alias': 'mountainbiking',
#   'title': 'Mountain Biking',
#   'parents': ['active']},
#  {'alias': 'mountainhuts',
#   'title': 'Mountain Huts',
#   'parents': ['hotels'],
#   'country_whitelist': ['DE',
#    'PL',
#    'US',
#    'NZ',
#    'AT',
#    'FR',
#    'ES',
#    'NO',
#    'SE',
#    'CH',
#    'CL',
#    'CZ',
#    'IT',
#    'AR']},
#  {'alias': 'movers', 'title': 'Movers', 'parents': ['homeservices']},
#  {'alias': 'movietheaters', 'title': 'Cinema', 'parents': ['arts']},
#  {'alias': 'muaythai', 'title': 'Muay Thai', 'parents': ['martialarts']},
#  {'alias': 'municipality',
#   'title': 'Municipality',
#   'parents': ['publicservicesgovt'],
#   'country_whitelist': ['US']},
#  {'alias': 'museums', 'title': 'Museums', 'parents': ['arts']},
#  {'alias': 'musicalinstrumentsandteachers',
#   'title': 'Musical Instruments & Teachers',
#   'parents': ['shopping']},
#  {'alias': 'musicians',
#   'title': 'Musicians',
#   'parents': ['eventservices'],
#   'country_blacklist': ['TR']},
#  {'alias': 'musicinstrumentservices',
#   'title': 'Musical Instrument Services',
#   'parents': ['localservices']},
#  {'alias': 'musicproduction',
#   'title': 'Music Production Services',
#   'parents': ['professional']},
#  {'alias': 'musicvenues',
#   'title': 'Music Venues',
#   'parents': ['arts', 'nightlife']},
#  {'alias': 'musicvideo', 'title': 'Music & DVDs', 'parents': ['media']},
#  {'alias': 'mystics',
#   'title': 'Mystics',
#   'parents': ['psychic_astrology'],
#   'country_blacklist': ['FR']},
#  {'alias': 'nailtechnicians',
#   'title': 'Nail Technicians',
#   'parents': ['othersalons'],
#   'country_blacklist': ['DE', 'JP', 'BR', 'TR', 'CH', 'AT', 'FR']},
#  {'alias': 'nannys',
#   'title': 'Nanny Services',
#   'parents': ['localservices'],
#   'country_blacklist': ['SE', 'FI']},
#  {'alias': 'napoletana',
#   'title': 'Napoletana',
#   'parents': ['italian'],
#   'country_whitelist': ['CZ', 'FR', 'IT']},
#  {'alias': 'nasilemak',
#   'title': 'Nasi Lemak',
#   'parents': ['food'],
#   'country_whitelist': ['MY', 'SG']},
#  {'alias': 'naturalgassuppliers',
#   'title': 'Natural Gas Suppliers',
#   'parents': ['utilities']},
#  {'alias': 'naturopathic',
#   'title': 'Naturopathic/Holistic',
#   'parents': ['physicians']},
#  {'alias': 'nephrologists',
#   'title': 'Nephrologists',
#   'parents': ['physicians'],
#   'country_blacklist': ['CH', 'AT', 'DE']},
#  {'alias': 'neurologist', 'title': 'Neurologist', 'parents': ['physicians']},
#  {'alias': 'neuropathologists',
#   'title': 'Neuropathologists',
#   'parents': ['physicians']},
#  {'alias': 'neurotologists',
#   'title': 'Neurotologists',
#   'parents': ['physicians'],
#   'country_blacklist': ['JP']},
#  {'alias': 'newamerican',
#   'title': 'American (New)',
#   'parents': ['restaurants'],
#   'country_whitelist': ['SE', 'IE', 'DK', 'GB', 'US', 'NO']},
#  {'alias': 'newcanadian',
#   'title': 'Canadian (New)',
#   'parents': ['restaurants'],
#   'country_whitelist': ['CA']},
#  {'alias': 'newmexican',
#   'title': 'New Mexican Cuisine',
#   'parents': ['restaurants'],
#   'country_whitelist': ['US']},
#  {'alias': 'newzealand',
#   'title': 'New Zealand',
#   'parents': ['restaurants'],
#   'country_whitelist': ['NZ']},
#  {'alias': 'nicaraguan',
#   'title': 'Nicaraguan',
#   'parents': ['restaurants'],
#   'country_blacklist': ['CL', 'AR']},
#  {'alias': 'nicois',
#   'title': 'Nicoise',
#   'parents': ['french'],
#   'country_whitelist': ['FR']},
#  {'alias': 'nightfood',
#   'title': 'Night Food',
#   'parents': ['restaurants'],
#   'country_whitelist': ['SE', 'DK', 'PL', 'TR', 'NO']},
#  {'alias': 'nightlife', 'title': 'Nightlife', 'parents': []},
#  {'alias': 'nikkei',
#   'title': 'Nikkei',
#   'parents': ['restaurants'],
#   'country_whitelist': ['MX', 'BR', 'CL', 'ES', 'AR']},
#  {'alias': 'nonprofit',
#   'title': 'Community Service/Non-Profit',
#   'parents': ['localservices']},
#  {'alias': 'noodles',
#   'title': 'Noodles',
#   'parents': ['restaurants'],
#   'country_blacklist': ['CH', 'AT', 'FR', 'DE']},
#  {'alias': 'norcinerie',
#   'title': 'Norcinerie',
#   'parents': ['restaurants'],
#   'country_whitelist': ['IT']},
#  {'alias': 'northeasternbrazilian',
#   'title': 'Northeastern Brazilian',
#   'parents': ['brazilian'],
#   'country_whitelist': ['BR']},
#  {'alias': 'northernbrazilian',
#   'title': 'Northern Brazilian',
#   'parents': ['brazilian'],
#   'country_whitelist': ['BR']},
#  {'alias': 'northerngerman',
#   'title': 'Northern German',
#   'parents': ['german'],
#   'country_whitelist': ['DE']},
#  {'alias': 'northernmexican',
#   'title': 'Northern Mexican',
#   'parents': ['mexican'],
#   'country_whitelist': ['MX']},
#  {'alias': 'norwegian',
#   'title': 'Traditional Norwegian',
#   'parents': ['restaurants'],
#   'country_whitelist': ['NO', 'FR']},
#  {'alias': 'notaries',
#   'title': 'Notaries',
#   'parents': ['localservices'],
#   'country_blacklist': ['NO']},
#  {'alias': 'nudist',
#   'title': 'Nudist',
#   'parents': ['active'],
#   'country_whitelist': ['DE',
#    'PT',
#    'NL',
#    'NZ',
#    'CA',
#    'FR',
#    'NO',
#    'SE',
#    'IE',
#    'DK',
#    'AU',
#    'PL',
#    'US',
#    'BR',
#    'AT',
#    'BE',
#    'FI',
#    'CH',
#    'GB',
#    'CZ']},
#  {'alias': 'nursepractitioner',
#   'title': 'Nurse Practitioner',
#   'parents': ['health']},
#  {'alias': 'nursingschools',
#   'title': 'Nursing Schools',
#   'parents': ['specialtyschools']},
#  {'alias': 'nutritionists', 'title': 'Nutritionists', 'parents': ['health']},
#  {'alias': 'nyonya',
#   'title': 'Nyonya',
#   'parents': ['malaysian'],
#   'country_whitelist': ['MY', 'AU']},
#  {'alias': 'oaxacan',
#   'title': 'Oaxacan',
#   'parents': ['mexican'],
#   'country_whitelist': ['MX']},
#  {'alias': 'obgyn',
#   'title': 'Obstetricians & Gynecologists',
#   'parents': ['physicians']},
#  {'alias': 'observatories', 'title': 'Observatories', 'parents': ['arts']},
#  {'alias': 'occupationaltherapy',
#   'title': 'Occupational Therapy',
#   'parents': ['health'],
#   'country_blacklist': ['SG',
#    'NZ',
#    'PH',
#    'FR',
#    'SE',
#    'TR',
#    'IT',
#    'MY',
#    'HK',
#    'PL',
#    'AT',
#    'JP',
#    'FI',
#    'CH',
#    'CZ',
#    'TW']},
#  {'alias': 'oden',
#   'title': 'Oden',
#   'parents': ['japanese'],
#   'country_whitelist': ['JP', 'TW']},
#  {'alias': 'officecleaning',
#   'title': 'Office Cleaning',
#   'parents': ['professional']},
#  {'alias': 'officeequipment',
#   'title': 'Office Equipment',
#   'parents': ['shopping']},
#  {'alias': 'officiants', 'title': 'Officiants', 'parents': ['eventservices']},
#  {'alias': 'oilchange',
#   'title': 'Oil Change Stations',
#   'parents': ['auto'],
#   'country_blacklist': ['CH', 'AT', 'SE', 'DE']},
#  {'alias': 'okinawan',
#   'title': 'Okinawan',
#   'parents': ['japanese'],
#   'country_whitelist': ['JP']},
#  {'alias': 'okonomiyaki',
#   'title': 'Okonomiyaki',
#   'parents': ['japanese'],
#   'country_whitelist': ['JP', 'TW']},
#  {'alias': 'oliveoil',
#   'title': 'Olive Oil',
#   'parents': ['gourmet'],
#   'country_whitelist': ['DE', 'BE', 'ES', 'AT', 'US', 'FR']},
#  {'alias': 'oncologist', 'title': 'Oncologist', 'parents': ['physicians']},
#  {'alias': 'onigiri',
#   'title': 'Onigiri',
#   'parents': ['japanese'],
#   'country_whitelist': ['JP', 'TW']},
#  {'alias': 'opensandwiches',
#   'title': 'Open Sandwiches',
#   'parents': ['restaurants'],
#   'country_whitelist': ['SE', 'NO', 'DK', 'TR']},
#  {'alias': 'opera', 'title': 'Opera & Ballet', 'parents': ['arts']},
#  {'alias': 'opthamalogists',
#   'title': 'Ophthalmologists',
#   'parents': ['physicians']},
#  {'alias': 'opticians',
#   'title': 'Eyewear & Opticians',
#   'parents': ['shopping']},
#  {'alias': 'optometrists',
#   'title': 'Optometrists',
#   'parents': ['health'],
#   'country_blacklist': ['CH', 'AT', 'DE']},
#  {'alias': 'oralsurgeons', 'title': 'Oral Surgeons', 'parents': ['dentists']},
#  {'alias': 'organdonorservices',
#   'title': 'Organ & Tissue Donor Services',
#   'parents': ['health'],
#   'country_whitelist': ['US']},
#  {'alias': 'organic_stores', 'title': 'Organic Stores', 'parents': ['food']},
#  {'alias': 'oriental',
#   'title': 'Oriental',
#   'parents': ['restaurants'],
#   'country_whitelist': ['DE', 'PT', 'CH', 'AT', 'FR']},
#  {'alias': 'orthodontists', 'title': 'Orthodontists', 'parents': ['dentists']},
#  {'alias': 'orthopedists', 'title': 'Orthopedists', 'parents': ['physicians']},
#  {'alias': 'orthotics',
#   'title': 'Orthotics',
#   'parents': ['health'],
#   'country_whitelist': ['AU',
#    'US',
#    'BR',
#    'SG',
#    'NZ',
#    'FR',
#    'NO',
#    'ES',
#    'IE',
#    'DK',
#    'FI',
#    'CZ',
#    'GB',
#    'IT']},
#  {'alias': 'osteopathicphysicians',
#   'title': 'Osteopathic Physicians',
#   'parents': ['physicians']},
#  {'alias': 'osteopaths',
#   'title': 'Osteopaths',
#   'parents': ['medcenters'],
#   'country_whitelist': ['AU']},
#  {'alias': 'othersalons', 'title': 'Nail Salons', 'parents': ['beautysvc']},
#  {'alias': 'otologists',
#   'title': 'Otologists',
#   'parents': ['physicians'],
#   'country_blacklist': ['CH', 'AT', 'FR', 'DE']},
#  {'alias': 'ottomancuisine',
#   'title': 'Ottoman Cuisine',
#   'parents': ['turkish'],
#   'country_whitelist': ['TR']},
#  {'alias': 'outdoorfurniture',
#   'title': 'Outdoor Furniture Stores',
#   'parents': ['homeandgarden']},
#  {'alias': 'outdoorgear', 'title': 'Outdoor Gear', 'parents': ['sportgoods']},
#  {'alias': 'outdoormovies',
#   'title': 'Outdoor Movies',
#   'parents': ['movietheaters'],
#   'country_blacklist': ['PL']},
#  {'alias': 'outlet_stores', 'title': 'Outlet Stores', 'parents': ['shopping']},
#  {'alias': 'oxygenbars',
#   'title': 'Oxygen Bars',
#   'parents': ['health'],
#   'country_whitelist': ['US']},
#  {'alias': 'oyakodon',
#   'title': 'Oyakodon',
#   'parents': ['donburi'],
#   'country_whitelist': ['JP']},
#  {'alias': 'pachinko',
#   'title': 'Pachinko',
#   'parents': ['arts'],
#   'country_whitelist': ['JP']},
#  {'alias': 'packingservices',
#   'title': 'Packing Services',
#   'parents': ['homeservices'],
#   'country_whitelist': ['MY',
#    'HK',
#    'PL',
#    'SG',
#    'PH',
#    'BE',
#    'FR',
#    'CA',
#    'CZ',
#    'US',
#    'TW']},
#  {'alias': 'packingsupplies',
#   'title': 'Packing Supplies',
#   'parents': ['shopping'],
#   'country_whitelist': ['DE',
#    'PT',
#    'SG',
#    'NL',
#    'NZ',
#    'CA',
#    'FR',
#    'NO',
#    'IE',
#    'DK',
#    'AU',
#    'US',
#    'BR',
#    'AT',
#    'BE',
#    'JP',
#    'CH',
#    'GB',
#    'CZ']},
#  {'alias': 'paddleboarding',
#   'title': 'Paddleboarding',
#   'parents': ['active'],
#   'country_blacklist': ['MY',
#    'HK',
#    'NL',
#    'PH',
#    'BE',
#    'CA',
#    'SE',
#    'JP',
#    'TR',
#    'GB',
#    'IT',
#    'TW']},
#  {'alias': 'painmanagement',
#   'title': 'Pain Management',
#   'parents': ['physicians']},
#  {'alias': 'paintandsip',
#   'title': 'Paint & Sip',
#   'parents': ['arts'],
#   'country_whitelist': ['US', 'HK']},
#  {'alias': 'paintball',
#   'title': 'Paintball',
#   'parents': ['active'],
#   'country_blacklist': ['SG']},
#  {'alias': 'painters', 'title': 'Painters', 'parents': ['homeservices']},
#  {'alias': 'paintstores',
#   'title': 'Paint Stores',
#   'parents': ['homeandgarden'],
#   'country_blacklist': ['MY', 'HK', 'PT', 'FI', 'TR', 'PH', 'TW']},
#  {'alias': 'paintyourownpottery',
#   'title': 'Paint-Your-Own Pottery',
#   'parents': ['artsandcrafts'],
#   'country_whitelist': ['MY', 'HK', 'DE', 'SG', 'PH', 'CA', 'US', 'TW']},
#  {'alias': 'pakistani', 'title': 'Pakistani', 'parents': ['restaurants']},
#  {'alias': 'palatine',
#   'title': 'Palatine',
#   'parents': ['german'],
#   'country_whitelist': ['DE']},
#  {'alias': 'panasian',
#   'title': 'Pan Asian',
#   'parents': ['restaurants'],
#   'country_blacklist': ['IT']},
#  {'alias': 'panzerotti',
#   'title': 'Panzerotti',
#   'parents': ['food'],
#   'country_whitelist': ['IT']},
#  {'alias': 'parasailing', 'title': 'Parasailing', 'parents': ['active']},
#  {'alias': 'parentingclasses',
#   'title': 'Parenting Classes',
#   'parents': ['specialtyschools']},
#  {'alias': 'parking', 'title': 'Parking', 'parents': ['auto']},
#  {'alias': 'parklets',
#   'title': 'Parklets',
#   'parents': ['localflavor'],
#   'country_whitelist': ['US']},
#  {'alias': 'parks', 'title': 'Parks', 'parents': ['active']},
#  ...]

# %%
type(categories)
# Out:
# list

# %% [markdown]
# ### Parent Categories

# %%
parent_cats = []

for cat in categories:
    if cat['parents']==[]:
        print(cat['alias'])
        parent_cats.append(cat['alias'])
# Out:
# active
# arts
# auto
# beautysvc
# bicycles
# education
# eventservices
# financialservices
# food
# health
# homeservices
# hotelstravel
# localflavor
# localservices
# massmedia
# nightlife
# pets
# professional
# publicservicesgovt
# religiousorgs
# restaurants
# shopping

# %%
len(parent_cats)
# Out:
# 22

# %% [markdown]
# ## Function to pull results from a ZIP code

# %%
def zip_query_to_df(zip_in, cats=['restaurants','shopping','nightlife',
                                  'hotelstravel','localservices','food',
                                  'eventservices','beautysvc','dryclean',
                                  'hair','bar']):
    
    api_key = '21Pt2l8__qgIdL0ZpgYC_yWblJ_O8_vJ3_-tIybHDyuQl9oVBXAzAXQWqMmIrz7idLyc7owv4-lfSON0QjKJN4pvQei4rUQAGSZcGcVTQc4HtBseUcztUPkVrAItXHYx'
    api_obj = YelpAPI(api_key, timeout_s=3.0)
    
    zip_results = pd.DataFrame(index=cats, columns=['one','two','three','four'])
    #print(zip_results)
    
    for cat in cats:
        print(cat)
        response = api_obj.search_query(location=str(zip_in), categories=[cat], 
                                        sort_by='distance', limit=50)
        res_df = pd.DataFrame(response['businesses'])
        #print(res_df.columns)
        for i in range(len(res_df)):
            if res_df['location'][i]['zip_code'] != str(zip_in):
                res_df.iloc[i, 11] = np.NaN
        
        try:
#             print(res_df[res_df.price.str.strip()=='$'])
#             print(res_df[res_df.price.str.strip()=='$$'])
#             print(res_df[res_df.price.str.strip()=='$$$'])
#             print(res_df[res_df.price.str.strip()=='$$$$'])
            
            one_ct = res_df[res_df.price.str.strip()=='$'].shape[0]
            two_ct = res_df[res_df.price.str.strip()=='$$'].shape[0]
            three_ct = res_df[res_df.price.str.strip()=='$$$'].shape[0]
            four_ct = res_df[res_df.price.str.strip()=='$$$$'].shape[0]
            
            zip_results.loc[cat,'one'] = res_df[res_df.price.str.strip()=='$'].shape[0]
            zip_results.loc[cat,'two'] = res_df[res_df.price.str.strip()=='$$'].shape[0]
            zip_results.loc[cat,'three'] = res_df[res_df.price.str.strip()=='$$$'].shape[0]
            zip_results.loc[cat,'four'] = res_df[res_df.price.str.strip()=='$$$$'].shape[0]
        except:
            pass
        #if one_ct + two_ct + three_ct + four_ct < 40:
        print(cat, '2')
        res2 = api_obj.search_query(location=str(zip_in), categories=[cat], 
                                    sort_by='distance', offset=50, limit=50)
        res2_df = pd.DataFrame(res2['businesses'])
        for j in range(len(res2_df)):
            if res2_df['location'][j]['zip_code'] != str(zip_in):
                res2_df.iloc[j, 11] = np.NaN
        try:
            zip_results.loc[cat,'one'] += res2_df[res2_df.price.str.strip()=='$'].shape[0]
            zip_results.loc[cat,'two'] += res2_df[res2_df.price.str.strip()=='$$'].shape[0]
            zip_results.loc[cat,'three'] += res2_df[res2_df.price.str.strip()=='$$$'].shape[0]
            zip_results.loc[cat,'four'] += res2_df[res2_df.price.str.strip()=='$$$$'].shape[0]
        except:
            pass 

    return zip_results

# %%
zip_query_to_df('19025')
# Out:
# restaurants
# restaurants 2
# shopping
# shopping 2
# nightlife
# nightlife 2
# hotelstravel
# hotelstravel 2
# localservices
# localservices 2
# food
# food 2
# eventservices
# eventservices 2
# beautysvc
# beautysvc 2
# dryclean
# dryclean 2
# hair
# hair 2
# bar
# bar 2
#                one  two  three  four
# restaurants      9    5      0     0
# shopping         0    2      0     0
# nightlife        0    0      0     0
# hotelstravel     0    0      0     0
# localservices    0    0      0     0
# food             2    4      1     0
# eventservices    0    0      0     0
# beautysvc        1    2      0     0
# dryclean         0    0      0     0
# hair             0    1      0     0
# bar              9    7      0     0

# %%
zip_query_to_df('10128')
# Out:
# restaurants
# restaurants 2
# shopping
# shopping 2
# nightlife
# nightlife 2
# hotelstravel
# hotelstravel 2
# localservices
# localservices 2
# food
# food 2
# eventservices
# eventservices 2
# beautysvc
# beautysvc 2
# dryclean
# dryclean 2
# hair
# hair 2
# bar
# bar 2
#                one  two  three  four
# restaurants     14   47      5     0
# shopping         6   32      5     5
# nightlife        6   18      2     0
# hotelstravel     0    3      1     0
# localservices    5   13      2     1
# food            17   32      2     5
# eventservices    1   10      1     1
# beautysvc       13   35      7     3
# dryclean         0    4      1     2
# hair             4   20      1     1
# bar             23   37      4     1

# %%
zip_query_to_df('10285')
# Out:
# restaurants
# restaurants 2
# shopping
# shopping 2
# nightlife
# nightlife 2
# hotelstravel
# hotelstravel 2
# localservices
# localservices 2
# food
# food 2
# eventservices
# eventservices 2
# beautysvc
# beautysvc 2
# dryclean
# dryclean 2
# hair
# hair 2
# bar
# bar 2
#                one  two  three  four
# restaurants      0    1      0     0
# shopping         0    0      0     0
# nightlife        0    0      0     0
# hotelstravel     0    0      0     0
# localservices    0    0      0     0
# food             0    0      0     0
# eventservices    0    0      0     0
# beautysvc        0    0      0     0
# dryclean         0    0      0     0
# hair             0    0      0     0
# bar              0    0      0     0

# %%
df2.sum().sum()
# Out:
# 8

# %%
df2
# Out:
#                    $  $$  $$$  $$$$
# restaurants        0   1    0     0
# shopping           0   0    0     0
# nightlife          0   0    0     0
# hotelstravel       0   0    0     0
# localservices      0   0    0     0
# food               1   2    0     0
# eventservices      0   0    0     0
# beautysvc          1   1    0     0
# dryclean           0   0    0     0
# hair               0   1    0     0
# mobilephonerepair  0   0    0     0
# bar                0   1    0     0

# %%
zip_query_to_df('10017')
# Out:
# restaurants
# restaurants 2
# shopping
# shopping 2
# nightlife
# nightlife 2
# hotelstravel
# hotelstravel 2
# localservices
# localservices 2
# food
# food 2
# eventservices
# eventservices 2
# beautysvc
# beautysvc 2
# dryclean
# dryclean 2
# hair
# hair 2
# bar
# bar 2
#                one  two  three  four
# restaurants     31   24      2     0
# shopping         2   26     11     5
# nightlife        2   32     13     3
# hotelstravel     0   14      5     0
# localservices    1    6      2     1
# food            14   18      5     0
# eventservices    0   21      9     1
# beautysvc       11   28     10     3
# dryclean         0    0      1     0
# hair             5   17      5     0
# bar             29   24      2     0

# %%
df3
# Out:
#                    one  two  three  four
# restaurants          2    1      1     1
# shopping             0    6      1     0
# nightlife            0    2      1     0
# hotelstravel         0    1      0     0
# localservices        0    0      0     0
# food                 2    3      0     0
# eventservices        0    1      2     0
# beautysvc            0    1      1     0
# dryclean             0    0      1     0
# hair                 0    1      1     0
# mobilephonerepair    0    2      0     0
# bar                  2    1      1     0

# %%
df4 = zip_query_to_df('90210')
# Out:
# restaurants
# shopping
# nightlife
# hotelstravel
# localservices
# food
# eventservices
# beautysvc
# dryclean
# hair
# bar
#                one  two  three  four
# restaurants      5   17      4     7
# shopping         2   11     13     3
# nightlife        0    5      7     6
# hotelstravel     0    3      2     1
# localservices    0    2      5     0
# food             8   22      7     0
# eventservices    0    4      4     2
# beautysvc        1   16      8     6
# dryclean         0    1      0     0
# hair             0   12     15     2
# bar              6   20      5     5

# %%
zip_query_to_df('10128')
# Out:
# restaurants
# shopping
# nightlife
# nightlife 2
# hotelstravel
# hotelstravel 2
# localservices
# localservices 2
# food
# eventservices
# eventservices 2
# beautysvc
# dryclean
# dryclean 2
# hair
# hair 2
# bar
#                one  two  three  four
# restaurants     14   31      3     0
# shopping         5   26      5     5
# nightlife        6   18      2     0
# hotelstravel     0    3      1     0
# localservices    5   13      2     1
# food            14   24      1     3
# eventservices    1   10      1     1
# beautysvc       10   28      4     2
# dryclean         0    4      1     2
# hair             4   20      1     1
# bar             14   28      3     0
#                one  two  three  four
# restaurants     14   31      3     0
# shopping         5   26      5     5
# nightlife        6   18      2     0
# hotelstravel     0    3      1     0
# localservices    5   13      2     1
# food            14   24      1     3
# eventservices    1   10      1     1
# beautysvc       10   28      4     2
# dryclean         0    4      1     2
# hair             4   20      1     1
# bar             14   28      3     0

# %%
def zip_query(zip_in, cats=['restaurants','shopping','localservices']):
    """Available arguments for zip_query: 
    zip_in: zip code (str)
    cats: categories (list) - default is ['restaurants','shopping','localservices']
    """
    
    api_key = '21Pt2l8__qgIdL0ZpgYC_yWblJ_O8_vJ3_-tIybHDyuQl9oVBXAzAXQWqMmIrz7idLyc7owv4-lfSON0QjKJN4pvQei4rUQAGSZcGcVTQc4HtBseUcztUPkVrAItXHYx'
    api_obj = YelpAPI(api_key, timeout_s=3.0)
    
    zip_results = pd.DataFrame(index=cats, columns=['1','2','3','4','returned'])
    
    for cat in cats:
        in_zip = True
        
        offset_val = 0
        return_ct = 0
        
        while in_zip:
            response = api_obj.search_query(location=zip_in, categories=[cat], 
                                            sort_by='distance', offset=offset_val, 
                                            limit=50)
            cat_df = pd.DataFrame(response['businesses'])
            return_ct += cat_df.shape[0]
            
            for i in range(len(cat_df)):
                if cat_df['location'][i]['zip_code'] != zip_in:
                    cat_df.iloc[i, 11] = '0' # index location for 'price' key is 11
                    in_zip = False
            
            zip_results.loc[cat,'1'] = cat_df[cat_df.price.str.strip()=='$'].shape[0]
            zip_results.loc[cat,'2'] = cat_df[cat_df.price.str.strip()=='$$'].shape[0]
            zip_results.loc[cat,'3'] = cat_df[cat_df.price.str.strip()=='$$$'].shape[0]
            zip_results.loc[cat,'4'] = cat_df[cat_df.price.str.strip()=='$$$$'].shape[0]
            
            offset_val += 50
        zip_results.loc[cat,'returned'] = return_ct
    return zip_results

# %%
zip_query('10128')
# Out:
#                 1   2  3  4  returned
# restaurants    14  31  3  0        50
# shopping        5  26  5  5        50
# localservices   4  10  4  2       100

# %% [markdown]
# ## Search query to dataframe

# %%
def query_to_df(loc_in, cat_in=['restaurants','shopping','localservices'], 
                sort_in='distance', limit_in=50, 
                cols=['categories','alias','city','state','zip_code','price','review_count','latitude','longitude']):
    """Available arguments:
    loc_in (str): location (zip, city, neighborhood, etc.)
    cat_in (list): categories - default is ['restaurants','shopping','localservices']
    sort_in (str): sort criterion of 'distance','best_match','review_count' - default is 'distance'
    limit_in (int): number of results to pull per category, max is 50 - default is 50
    cols (list): columns for dataframe, matching API results key names - default is
    ['categories','alias','city','state','zip_code','price','review_count','latitude','longitude']
    """
    api_key = '21Pt2l8__qgIdL0ZpgYC_yWblJ_O8_vJ3_-tIybHDyuQl9oVBXAzAXQWqMmIrz7idLyc7owv4-lfSON0QjKJN4pvQei4rUQAGSZcGcVTQc4HtBseUcztUPkVrAItXHYx'
    api_obj = YelpAPI(api_key, timeout_s=3.0)
    
    output_df = pd.DataFrame(columns=['search_term']+cols)
    
    limit_list = []
    if limit_in > 50:
        req = limit_in
        while req > 50:
            limit_list.append(50)
            req -= 50
        limit_list.append(req)
    else:
        limit_list.append(limit_in)
    
    for cat in cat_in:
        cat_df = pd.DataFrame(columns=['search_term']+cols)
        for j, limit in enumerate(limit_list):
            response = api_obj.search_query(location=loc_in, categories=[cat], sort_by=sort_in, limit=limit, offset=(j*50))
            response_df = pd.DataFrame(response['businesses'])            
            iter_df = pd.DataFrame(columns=['search_term']+cols)
            iter_df['search_term'] = [cat for i in range(len(response_df))]

            for col_name in cols:
                if col_name == 'categories':
                    for k, cell in enumerate(response_df['categories']):
                        iter_cat_str = ''
                        for d in cell:
                            iter_cat_str += str(d['alias']+', ')
                        iter_df.loc[k, 'categories'] = iter_cat_str[:-2]                    
                elif col_name in ('city','state','zip_code'):
                    iter_df[col_name] = [response_df['location'][i][col_name] for i in range(response_df.shape[0])]
                elif col_name in ('latitude','longitude'):
                    iter_df[col_name] = [response_df['coordinates'][i][col_name] for i in range(response_df.shape[0])]
                else:
                    iter_df[col_name] = response_df[col_name]
            cat_df = cat_df.append(iter_df)
        output_df = output_df.append(cat_df)
    output_df.index = range(output_df.shape[0])
    
    return output_df

# %%
test_df = query_to_df('10128', limit_in=70, cat_in=['restaurants'])

# %%
test_df.shape
# Out:
# (70, 9)

# %%
zip_query('10128')
# Out:
#                 1   2  3  4  returned
# restaurants    14  31  3  0        50
# shopping        5  26  5  5        50
# localservices   4  10  4  2       100

# %%
test_df.groupby('search_term').price.value_counts()
# Out:
# search_term    price
# localservices  $$        7
#                $         4
#                $$$       2
#                $$$$      1
# restaurants    $$       31
#                $        14
#                $$$       3
# shopping       $$       27
#                $         5
#                $$$       5
#                $$$$      5
# Name: price, dtype: int64

# %%
test_df.groupby('search_term').price.value_counts()
# Out:
# search_term  price
# restaurants  $$       47
#              $        14
#              $$$       5
# Name: price, dtype: int64

# %%
test_df.groupby('search_term').zip_code.value_counts()
# Out:
# search_term  zip_code
# restaurants  10128       69
#              10028        1
# Name: zip_code, dtype: int64

# %%
test_df.alias.value_counts()
# Out:
# the-filmore-delicatessen-new-york             1
# flip-sigi-new-york-3                          1
# green-cafe-new-york-12                        1
# midnight-express-diner-new-york               1
# cafe-d-alsace-new-york                        1
# corrado-bread-and-pastry-cafe-new-york        1
# le-viet-cafe-new-york                         1
# kaia-wine-bar-new-york                        1
# zesty-pizzeria-and-salumeria-new-york-2       1
# milano-market-new-york-2                      1
# korali-estiatorio-new-york                    1
# al-giorgios-manhattan                         1
# roma-pizza-new-york-4                         1
# pic-up-stix-new-york-2                        1
# corner-cafe-and-bakery-new-york-3             1
# ooki-sushi-new-york                           1
# libertador-new-york                           1
# 3rd-avenue-garden-new-york                    1
# oaxaca-taqueria-new-york-12                   1
# tacos-mi-mexico-new-york-2                    1
# delizia-92-new-york                           1
# sfoglia-restaurant-new-york                   1
# isohama-new-york                              1
# selena-rosa-new-york                          1
# ashoka-on-2nd-avenue-new-york                 1
# the-milton-new-york                           1
# vietnaam-new-york                             1
# the-writing-room-new-york                     1
# tab-grocery-deli-new-york                     1
# maroo-new-york                                1
#                                              ..
# third-avenue-ale-house-new-york               1
# new-york-hot-and-fresh-bagels-new-york        1
# raku-raku-new-york                            1
# effys-cafe-new-york-4                         1
# wok-88-new-york                               1
# naruto-ramen-new-york                         1
# infirmary-new-york                            1
# 1742-wine-bar-new-york                        1
# mole-new-york-6                               1
# dominos-pizza-new-york-11                     1
# lex-restaurant-new-york                       1
# two-door-tavern-new-york-2                    1
# san-matteo-pizza-and-espresso-bar-new-york    1
# thais-new-york-new-york-2                     1
# san-matteo-takeaway-new-york                  1
# shoga-sushi-and-oyster-bar-new-york-2         1
# rathbones-restaurant-new-york                 1
# chochin-new-york-2                            1
# the-corner-restaurant-new-york                1
# ottos-tacos-new-york-5                        1
# pye-boat-noodle-new-york-3                    1
# le-pain-quotidien-new-york-143                1
# lexington-grill-new-york                      1
# bellini-pizza-and-mediterranean-new-york      1
# the-district-new-york                         1
# il-carino-restaurant-new-york                 1
# barking-dog-new-york-4                        1
# chinatown-restaurant-new-york-3               1
# peri-ela-new-york                             1
# siena-cafe-new-york-3                         1
# Name: alias, Length: 70, dtype: int64

# %%
test_df
# Out:
#     search_term                                categories  \
# 0   restaurants                  catering, delis, grocery
# 1   restaurants            wine_bars, southafrican, tapas
# 2   restaurants                          japanese, korean
# 3   restaurants                                     ramen
# 4   restaurants                              tradamerican
# 5   restaurants                       mexican, foodtrucks
# 6   restaurants         bakeries, breakfast_brunch, cafes
# 7   restaurants                             bagels, delis
# 8   restaurants   tradamerican, gastropubs, beer_and_wine
# 9   restaurants                  japanese, chinese, sushi
# 10  restaurants          pizza, chicken_wings, sandwiches
# 11  restaurants                   delis, gourmet, grocery
# 12  restaurants                                      thai
# 13  restaurants            breakfast_brunch, tradamerican
# 14  restaurants                                     cafes
# 15  restaurants                        convenience, delis
# 16  restaurants                      italian, bars, cafes
# 17  restaurants                                   mexican
# 18  restaurants                          pizza, wine_bars
# 19  restaurants                      pizza, mediterranean
# 20  restaurants                                   turkish
# 21  restaurants                 bakeries, desserts, cafes
# 22  restaurants          newamerican, eventplanning, bars
# 23  restaurants                     italian, pizza, salad
# 24  restaurants                           sushi, japanese
# 25  restaurants                                   italian
# 26  restaurants                          mexican, burgers
# 27  restaurants             vietnamese, thai, asianfusion
# 28  restaurants                          argentine, steak
# 29  restaurants                                  filipino
# ..          ...                                       ...
# 40  restaurants                                     tacos
# 41  restaurants                                   chinese
# 42  restaurants                      diners, tradamerican
# 43  restaurants                                    indpak
# 44  restaurants                           japanese, sushi
# 45  restaurants                             thai, noodles
# 46  restaurants                       cajun, cocktailbars
# 47  restaurants                            pizza, italian
# 48  restaurants                                   mexican
# 49  restaurants                       delis, tradamerican
# 50  restaurants                                    indpak
# 51  restaurants                            pizza, italian
# 52  restaurants                                   italian
# 53  restaurants                           japanese, sushi
# 54  restaurants                 bars, steak, tradamerican
# 55  restaurants                                   mexican
# 56  restaurants                           japanese, sushi
# 57  restaurants                             bars, burgers
# 58  restaurants                                   italian
# 59  restaurants                        bars, tradamerican
# 60  restaurants                                     greek
# 61  restaurants                   gastropubs, newamerican
# 62  restaurants        french, breakfast_brunch, desserts
# 63  restaurants                        pubs, tradamerican
# 64  restaurants  tradamerican, desserts, breakfast_brunch
# 65  restaurants                    vietnamese, sandwiches
# 66  restaurants       cafes, breakfast_brunch, sandwiches
# 67  restaurants        coffee, breakfast_brunch, bakeries
# 68  restaurants                              sushi, ramen
# 69  restaurants                                  japanese
#
#                                          alias       city state zip_code  \
# 0                   3rd-avenue-garden-new-york   New York    NY    10128
# 1                       kaia-wine-bar-new-york   New York    NY    10128
# 2                               maroo-new-york   New York    NY    10128
# 3                        naruto-ramen-new-york   New York    NY    10128
# 4               the-corner-restaurant-new-york   New York    NY    10128
# 5                   tacos-mi-mexico-new-york-2   New York    NY    10128
# 6            corner-cafe-and-bakery-new-york-3   New York    NY    10128
# 7       new-york-hot-and-fresh-bagels-new-york   New York    NY    10128
# 8              third-avenue-ale-house-new-york   New York    NY    10128
# 9              chinatown-restaurant-new-york-3   New York    NY    10128
# 10                   dominos-pizza-new-york-11   New York    NY    10128
# 11                    milano-market-new-york-2   New York    NY    10128
# 12                   thais-new-york-new-york-2   New York    NY    10128
# 13                       effys-cafe-new-york-8   New York    NY    10028
# 14                       effys-cafe-new-york-4   New York    NY    10128
# 15                   tab-grocery-deli-new-york   New York    NY    10128
# 16                       siena-cafe-new-york-3   New York    NY    10128
# 17                             mole-new-york-6   New York    NY    10128
# 18  san-matteo-pizza-and-espresso-bar-new-york   New York    NY    10128
# 19    bellini-pizza-and-mediterranean-new-york   New York    NY    10128
# 20                           peri-ela-new-york   New York    NY    10128
# 21      corrado-bread-and-pastry-cafe-new-york   New York    NY    10128
# 22                  two-door-tavern-new-york-2   New York    NY    10128
# 23                san-matteo-takeaway-new-york   New York    NY    10128
# 24                         ooki-sushi-new-york   New York    NY    10128
# 25                       al-giorgios-manhattan  Manhattan    NY    10128
# 26                    lolitas-kitchen-new-york   New York    NY    10128
# 27                       le-viet-cafe-new-york   New York    NY    10128
# 28                         libertador-new-york   New York    NY    10128
# 29                        flip-sigi-new-york-3   New York    NY    10128
# ..                                         ...        ...   ...      ...
# 40                      ottos-tacos-new-york-5   New York    NY    10128
# 41                      pic-up-stix-new-york-2   New York    NY    10128
# 42             midnight-express-diner-new-york   New York    NY    10128
# 43           mughlai-indian-cuisine-new-york-4   New York    NY    10128
# 44                            isohama-new-york   New York    NY    10128
# 45                  pye-boat-noodle-new-york-3   New York    NY    10128
# 46                          infirmary-new-york   New York    NY    10128
# 47                         delizia-92-new-york   New York    NY    10128
# 48                 oaxaca-taqueria-new-york-12   New York    NY    10128
# 49           the-filmore-delicatessen-new-york   New York    NY    10128
# 50               ashoka-on-2nd-avenue-new-york   New York    NY    10128
# 51     zesty-pizzeria-and-salumeria-new-york-2   New York    NY    10128
# 52                 sfoglia-restaurant-new-york   New York    NY    10128
# 53                          tenzan-89-new-york   New York    NY    10128
# 54                   the-writing-room-new-york   New York    NY    10128
# 55                        selena-rosa-new-york   New York    NY    10128
# 56                          raku-raku-new-york   New York    NY    10128
# 57                       pour-house-new-york-2   New York    NY    10128
# 58               il-carino-restaurant-new-york   New York    NY    10128
# 59         genesis-bar-and-restaurant-new-york   New York    NY    10128
# 60                    lexington-grill-new-york   New York    NY    10128
# 61                       the-district-new-york   New York    NY    10128
# 62                      cafe-d-alsace-new-york   New York    NY    10128
# 63               rathbones-restaurant-new-york   New York    NY    10128
# 64                      barking-dog-new-york-4   New York    NY    10128
# 65                           vietnaam-new-york   New York    NY    10128
# 66                      green-cafe-new-york-12   New York    NY    10128
# 67              le-pain-quotidien-new-york-143   New York    NY    10128
# 68       shoga-sushi-and-oyster-bar-new-york-2   New York    NY    10128
# 69                          chochin-new-york-2   New York    NY    10128
#
#    price review_count   latitude  longitude
# 0     $$           15  40.781930 -73.951940
# 1     $$          377  40.781900 -73.951970
# 2     $$          120  40.782476 -73.951333
# 3     $$          852  40.781170 -73.952500
# 4    $$$           13  40.782630 -73.951210
# 5      $            9  40.780840 -73.951100
# 6     $$          258  40.782690 -73.950940
# 7      $           70  40.780710 -73.952180
# 8     $$          271  40.782800 -73.951290
# 9     $$          245  40.782860 -73.951260
# 10     $           36  40.780420 -73.952160
# 11    $$          194  40.780710 -73.952830
# 12    $$          117  40.781299 -73.949474
# 13   NaN            1  40.783170 -73.952780
# 14     $           15  40.782913 -73.952889
# 15   NaN            5  40.780392 -73.950264
# 16    $$          139  40.780730 -73.953000
# 17    $$          335  40.780331 -73.950302
# 18    $$          450  40.780400 -73.950120
# 19     $            4  40.783170 -73.951020
# 20   $$$           75  40.782180 -73.953440
# 21     $           52  40.782180 -73.953440
# 22    $$          112  40.780635 -73.953071
# 23    $$          139  40.780168 -73.950290
# 24    $$          235  40.780290 -73.952540
# 25    $$            3  40.780750 -73.949420
# 26     $           76  40.782421 -73.953450
# 27    $$          108  40.781160 -73.949130
# 28    $$          412  40.779980 -73.950430
# 29    $$          163  40.781272 -73.949076
# ..   ...          ...        ...        ...
# 40    $$          106  40.780300 -73.953120
# 41     $           57  40.782590 -73.953520
# 42    $$          366  40.779790 -73.950580
# 43    $$          371  40.780020 -73.949780
# 44    $$          139  40.783610 -73.950880
# 45    $$          375  40.779697 -73.950767
# 46    $$          475  40.779951 -73.949863
# 47     $          208  40.781480 -73.948750
# 48     $           71  40.779640 -73.950810
# 49    $$           64  40.783674 -73.950844
# 50    $$           64  40.779855 -73.950090
# 51    $$           75  40.783730 -73.950798
# 52   $$$          262  40.783535 -73.952719
# 53    $$          150  40.779579 -73.950103
# 54   $$$          427  40.779460 -73.950940
# 55    $$          258  40.779514 -73.950149
# 56   NaN            4  40.779600 -73.950080
# 57   NaN            2  40.779450 -73.950190
# 58    $$           44  40.779450 -73.950190
# 59    $$          212  40.779392 -73.950233
# 60    $$            6  40.781370 -73.954390
# 61    $$          322  40.783851 -73.949892
# 62    $$         1106  40.779160 -73.951040
# 63    $$          232  40.779210 -73.950370
# 64    $$          464  40.784120 -73.950520
# 65    $$          671  40.779148 -73.950417
# 66    $$           76  40.781071 -73.954674
# 67    $$          176  40.780470 -73.954479
# 68    $$          198  40.779055 -73.950793
# 69    $$           78  40.781805 -73.947887
#
# [70 rows x 10 columns]

# %%
test_df.describe()
# Out:
#         latitude  longitude
# count  70.000000  70.000000
# mean   40.781166 -73.951206
# std     0.001410   0.001578
# min    40.779055 -73.954674
# 25%    40.780040 -73.952674
# 50%    40.780795 -73.950862
# 75%    40.782462 -73.950127
# max    40.784120 -73.947887

# %%
test_df.describe(include=[np.object])
# Out:
#         search_term categories                              alias      city  \
# count            70         70                                 70        70
# unique            1         57                                 70         2
# top     restaurants    italian  the-filmore-delicatessen-new-york  New York
# freq             70          4                                  1        69
#
#        state zip_code price  review_count
# count     70       70    66            70
# unique     1        2     3            61
# top       NY    10128    $$           139
# freq      70       69    47             3
